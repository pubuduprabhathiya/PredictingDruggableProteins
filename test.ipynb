# %%
from propy import PyPro
import pandas as pd
import numpy as np

# %%
data_dir = 'raw_fasta'

def extractProteinSequenceFromFasta(file):
    # read text file in FASTA format
    with open(file, 'r') as f:
        lines = f.readlines()
    # remove new line characters
    lines = [line.strip() for line in lines]
    # remove empty lines
    lines = [line for line in lines if line != '']
    # odd ids are protein sequences
    protein_sequences = lines[1::2]
    # even ids are protein ids
    protein_ids = lines[::2]
    # return protein sequences
    return protein_ids, protein_sequences

# function to extract AAC features from a given FASTA format txt file using propy3
def extractFeatureDF(protein_ids, protein_sequences, feature_type, negative):
    df = pd.DataFrame()
    # iterate over protein sequences
    for i in range(len(protein_sequences)):
        try:
            # get protein sequence
            protein = PyPro.GetProDes(protein_sequences[i])
            if feature_type == 'AAC':
                extractedFeatures = protein.GetAAComp()
            elif feature_type == 'APAAC':
                extractedFeatures = protein.GetAPAAC()
            elif feature_type == 'CTD':
                extractedFeatures = protein.GetCTD()
            elif feature_type == 'PAAC':
                extractedFeatures = protein.GetPAAC()
            elif feature_type == 'DPC':
                extractedFeatures = protein.GetDPComp()
            # convert dictionary to pandas dataframe
            df1 = pd.DataFrame.from_dict(extractedFeatures, orient='index').transpose()
            df1['id'] = protein_ids[i][1:]
            # add dataframe to main dataframe with df.concat
            df = pd.concat([df, df1], ignore_index=True)
            print(feature_type, f"Extracted features for sequence {i}", negative)
        except ZeroDivisionError:
            print(f"Skipping sequence {i} due to ZeroDivisionError")
            continue
    if negative:
        df['label'] = 0
    else:
        df['label'] = 1
    # return AAC features dataframe
    return df

def combineNegativeAndPositiveDFs(negativeFile, positiveFile, feature_type):
    # extract protein ids and sequences from negative FASTA file
    negative_ids, negative_sequences = extractProteinSequenceFromFasta(negativeFile)
    # extract protein ids and sequences from positive FASTA file
    positive_ids, positive_sequences = extractProteinSequenceFromFasta(positiveFile)
    # extract feature_type from negative FASTA file
    negativeDF = extractFeatureDF(negative_ids, negative_sequences, feature_type, negative=True)
    # extract feature_type from positive FASTA file
    positiveDF = extractFeatureDF(positive_ids, positive_sequences, feature_type, negative=False)
    # combine positive and negative dataframes
    combinedDF = pd.concat([negativeDF, positiveDF], ignore_index=True)
    # shuffle dataframe
    combinedDF = combinedDF.sample(frac=1).reset_index(drop=True)
    # return combined dataframe
    return combinedDF

# %%
combineNegativeAndPositiveDFs(f'{data_dir}/TR_neg_SPIDER.txt', f'{data_dir}/TR_pos_SPIDER.txt', 'AAC').to_csv(f'processed_dataset/TR_AAC.csv', index=False)
combineNegativeAndPositiveDFs(f'{data_dir}/TR_neg_SPIDER.txt', f'{data_dir}/TR_pos_SPIDER.txt', 'APAAC').to_csv(f'processed_dataset/TR_APAAC.csv', index=False)
combineNegativeAndPositiveDFs(f'{data_dir}/TR_neg_SPIDER.txt', f'{data_dir}/TR_pos_SPIDER.txt', 'CTD').to_csv(f'processed_dataset/TR_CTD.csv', index=False)
combineNegativeAndPositiveDFs(f'{data_dir}/TR_neg_SPIDER.txt', f'{data_dir}/TR_pos_SPIDER.txt', 'PAAC').to_csv(f'processed_dataset/TR_PAAC.csv', index=False)
combineNegativeAndPositiveDFs(f'{data_dir}/TR_neg_SPIDER.txt', f'{data_dir}/TR_pos_SPIDER.txt', 'DPC').to_csv(f'processed_dataset/TR_DPC.csv', index=False)
# Out:
# AAC Extracted features for sequence 0 True
# AAC Extracted features for sequence 1 True
# AAC Extracted features for sequence 2 True
# AAC Extracted features for sequence 3 True
# AAC Extracted features for sequence 4 True
# AAC Extracted features for sequence 5 True
# AAC Extracted features for sequence 6 True
# AAC Extracted features for sequence 7 True
# AAC Extracted features for sequence 8 True
# AAC Extracted features for sequence 9 True
# AAC Extracted features for sequence 10 True
# AAC Extracted features for sequence 11 True
# AAC Extracted features for sequence 12 True
# AAC Extracted features for sequence 13 True
# AAC Extracted features for sequence 14 True
# AAC Extracted features for sequence 15 True
# AAC Extracted features for sequence 16 True
# AAC Extracted features for sequence 17 True
# AAC Extracted features for sequence 18 True
# AAC Extracted features for sequence 19 True
# AAC Extracted features for sequence 20 True
# AAC Extracted features for sequence 21 True
# AAC Extracted features for sequence 22 True
# AAC Extracted features for sequence 23 True
# AAC Extracted features for sequence 24 True
# AAC Extracted features for sequence 25 True
# AAC Extracted features for sequence 26 True
# AAC Extracted features for sequence 27 True
# AAC Extracted features for sequence 28 True
# AAC Extracted features for sequence 29 True
# AAC Extracted features for sequence 30 True
# AAC Extracted features for sequence 31 True
# AAC Extracted features for sequence 32 True
# AAC Extracted features for sequence 33 True
# AAC Extracted features for sequence 34 True
# AAC Extracted features for sequence 35 True
# AAC Extracted features for sequence 36 True
# AAC Extracted features for sequence 37 True
# AAC Extracted features for sequence 38 True
# AAC Extracted features for sequence 39 True
# AAC Extracted features for sequence 40 True
# AAC Extracted features for sequence 41 True
# AAC Extracted features for sequence 42 True
# AAC Extracted features for sequence 43 True
# AAC Extracted features for sequence 44 True
# AAC Extracted features for sequence 45 True
# AAC Extracted features for sequence 46 True
# AAC Extracted features for sequence 47 True
# AAC Extracted features for sequence 48 True
# AAC Extracted features for sequence 49 True
# AAC Extracted features for sequence 50 True
# AAC Extracted features for sequence 51 True
# AAC Extracted features for sequence 52 True
# AAC Extracted features for sequence 53 True
# AAC Extracted features for sequence 54 True
# AAC Extracted features for sequence 55 True
# AAC Extracted features for sequence 56 True
# AAC Extracted features for sequence 57 True
# AAC Extracted features for sequence 58 True
# AAC Extracted features for sequence 59 True
# AAC Extracted features for sequence 60 True
# AAC Extracted features for sequence 61 True
# AAC Extracted features for sequence 62 True
# AAC Extracted features for sequence 63 True
# AAC Extracted features for sequence 64 True
# AAC Extracted features for sequence 65 True
# AAC Extracted features for sequence 66 True
# AAC Extracted features for sequence 67 True
# AAC Extracted features for sequence 68 True
# AAC Extracted features for sequence 69 True
# AAC Extracted features for sequence 70 True
# AAC Extracted features for sequence 71 True
# AAC Extracted features for sequence 72 True
# AAC Extracted features for sequence 73 True
# AAC Extracted features for sequence 74 True
# AAC Extracted features for sequence 75 True
# AAC Extracted features for sequence 76 True
# AAC Extracted features for sequence 77 True
# AAC Extracted features for sequence 78 True
# AAC Extracted features for sequence 79 True
# AAC Extracted features for sequence 80 True
# AAC Extracted features for sequence 81 True
# AAC Extracted features for sequence 82 True
# AAC Extracted features for sequence 83 True
# AAC Extracted features for sequence 84 True
# AAC Extracted features for sequence 85 True
# AAC Extracted features for sequence 86 True
# AAC Extracted features for sequence 87 True
# AAC Extracted features for sequence 88 True
# AAC Extracted features for sequence 89 True
# AAC Extracted features for sequence 90 True
# AAC Extracted features for sequence 91 True
# AAC Extracted features for sequence 92 True
# AAC Extracted features for sequence 93 True
# AAC Extracted features for sequence 94 True
# AAC Extracted features for sequence 95 True
# AAC Extracted features for sequence 96 True
# AAC Extracted features for sequence 97 True
# AAC Extracted features for sequence 98 True
# AAC Extracted features for sequence 99 True
# AAC Extracted features for sequence 100 True
# AAC Extracted features for sequence 101 True
# AAC Extracted features for sequence 102 True
# AAC Extracted features for sequence 103 True
# AAC Extracted features for sequence 104 True
# AAC Extracted features for sequence 105 True
# AAC Extracted features for sequence 106 True
# AAC Extracted features for sequence 107 True
# AAC Extracted features for sequence 108 True
# AAC Extracted features for sequence 109 True
# AAC Extracted features for sequence 110 True
# AAC Extracted features for sequence 111 True
# AAC Extracted features for sequence 112 True
# AAC Extracted features for sequence 113 True
# AAC Extracted features for sequence 114 True
# AAC Extracted features for sequence 115 True
# AAC Extracted features for sequence 116 True
# AAC Extracted features for sequence 117 True
# AAC Extracted features for sequence 118 True
# AAC Extracted features for sequence 119 True
# AAC Extracted features for sequence 120 True
# AAC Extracted features for sequence 121 True
# AAC Extracted features for sequence 122 True
# AAC Extracted features for sequence 123 True
# AAC Extracted features for sequence 124 True
# AAC Extracted features for sequence 125 True
# AAC Extracted features for sequence 126 True
# AAC Extracted features for sequence 127 True
# AAC Extracted features for sequence 128 True
# AAC Extracted features for sequence 129 True
# AAC Extracted features for sequence 130 True
# AAC Extracted features for sequence 131 True
# AAC Extracted features for sequence 132 True
# AAC Extracted features for sequence 133 True
# AAC Extracted features for sequence 134 True
# AAC Extracted features for sequence 135 True
# AAC Extracted features for sequence 136 True
# AAC Extracted features for sequence 137 True
# AAC Extracted features for sequence 138 True
# AAC Extracted features for sequence 139 True
# AAC Extracted features for sequence 140 True
# AAC Extracted features for sequence 141 True
# AAC Extracted features for sequence 142 True
# AAC Extracted features for sequence 143 True
# AAC Extracted features for sequence 144 True
# AAC Extracted features for sequence 145 True
# AAC Extracted features for sequence 146 True
# AAC Extracted features for sequence 147 True
# AAC Extracted features for sequence 148 True
# AAC Extracted features for sequence 149 True
# AAC Extracted features for sequence 150 True
# AAC Extracted features for sequence 151 True
# AAC Extracted features for sequence 152 True
# AAC Extracted features for sequence 153 True
# AAC Extracted features for sequence 154 True
# AAC Extracted features for sequence 155 True
# AAC Extracted features for sequence 156 True
# AAC Extracted features for sequence 157 True
# AAC Extracted features for sequence 158 True
# AAC Extracted features for sequence 159 True
# AAC Extracted features for sequence 160 True
# AAC Extracted features for sequence 161 True
# AAC Extracted features for sequence 162 True
# AAC Extracted features for sequence 163 True
# AAC Extracted features for sequence 164 True
# AAC Extracted features for sequence 165 True
# AAC Extracted features for sequence 166 True
# AAC Extracted features for sequence 167 True
# AAC Extracted features for sequence 168 True
# AAC Extracted features for sequence 169 True
# AAC Extracted features for sequence 170 True
# AAC Extracted features for sequence 171 True
# AAC Extracted features for sequence 172 True
# AAC Extracted features for sequence 173 True
# AAC Extracted features for sequence 174 True
# AAC Extracted features for sequence 175 True
# AAC Extracted features for sequence 176 True
# AAC Extracted features for sequence 177 True
# AAC Extracted features for sequence 178 True
# AAC Extracted features for sequence 179 True
# AAC Extracted features for sequence 180 True
# AAC Extracted features for sequence 181 True
# AAC Extracted features for sequence 182 True
# AAC Extracted features for sequence 183 True
# AAC Extracted features for sequence 184 True
# AAC Extracted features for sequence 185 True
# AAC Extracted features for sequence 186 True
# AAC Extracted features for sequence 187 True
# AAC Extracted features for sequence 188 True
# AAC Extracted features for sequence 189 True
# AAC Extracted features for sequence 190 True
# AAC Extracted features for sequence 191 True
# AAC Extracted features for sequence 192 True
# AAC Extracted features for sequence 193 True
# AAC Extracted features for sequence 194 True
# AAC Extracted features for sequence 195 True
# AAC Extracted features for sequence 196 True
# AAC Extracted features for sequence 197 True
# AAC Extracted features for sequence 198 True
# AAC Extracted features for sequence 199 True
# AAC Extracted features for sequence 200 True
# AAC Extracted features for sequence 201 True
# AAC Extracted features for sequence 202 True
# AAC Extracted features for sequence 203 True
# AAC Extracted features for sequence 204 True
# AAC Extracted features for sequence 205 True
# AAC Extracted features for sequence 206 True
# AAC Extracted features for sequence 207 True
# AAC Extracted features for sequence 208 True
# AAC Extracted features for sequence 209 True
# AAC Extracted features for sequence 210 True
# AAC Extracted features for sequence 211 True
# AAC Extracted features for sequence 212 True
# AAC Extracted features for sequence 213 True
# AAC Extracted features for sequence 214 True
# AAC Extracted features for sequence 215 True
# AAC Extracted features for sequence 216 True
# AAC Extracted features for sequence 217 True
# AAC Extracted features for sequence 218 True
# AAC Extracted features for sequence 219 True
# AAC Extracted features for sequence 220 True
# AAC Extracted features for sequence 221 True
# AAC Extracted features for sequence 222 True
# AAC Extracted features for sequence 223 True
# AAC Extracted features for sequence 224 True
# AAC Extracted features for sequence 225 True
# AAC Extracted features for sequence 226 True
# AAC Extracted features for sequence 227 True
# AAC Extracted features for sequence 228 True
# AAC Extracted features for sequence 229 True
# AAC Extracted features for sequence 230 True
# AAC Extracted features for sequence 231 True
# AAC Extracted features for sequence 232 True
# AAC Extracted features for sequence 233 True
# AAC Extracted features for sequence 234 True
# AAC Extracted features for sequence 235 True
# AAC Extracted features for sequence 236 True
# AAC Extracted features for sequence 237 True
# AAC Extracted features for sequence 238 True
# AAC Extracted features for sequence 239 True
# AAC Extracted features for sequence 240 True
# AAC Extracted features for sequence 241 True
# AAC Extracted features for sequence 242 True
# AAC Extracted features for sequence 243 True
# AAC Extracted features for sequence 244 True
# AAC Extracted features for sequence 245 True
# AAC Extracted features for sequence 246 True
# AAC Extracted features for sequence 247 True
# AAC Extracted features for sequence 248 True
# AAC Extracted features for sequence 249 True
# AAC Extracted features for sequence 250 True
# AAC Extracted features for sequence 251 True
# AAC Extracted features for sequence 252 True
# AAC Extracted features for sequence 253 True
# AAC Extracted features for sequence 254 True
# AAC Extracted features for sequence 255 True
# AAC Extracted features for sequence 256 True
# AAC Extracted features for sequence 257 True
# AAC Extracted features for sequence 258 True
# AAC Extracted features for sequence 259 True
# AAC Extracted features for sequence 260 True
# AAC Extracted features for sequence 261 True
# AAC Extracted features for sequence 262 True
# AAC Extracted features for sequence 263 True
# AAC Extracted features for sequence 264 True
# AAC Extracted features for sequence 265 True
# AAC Extracted features for sequence 266 True
# AAC Extracted features for sequence 267 True
# AAC Extracted features for sequence 268 True
# AAC Extracted features for sequence 269 True
# AAC Extracted features for sequence 270 True
# AAC Extracted features for sequence 271 True
# AAC Extracted features for sequence 272 True
# AAC Extracted features for sequence 273 True
# AAC Extracted features for sequence 274 True
# AAC Extracted features for sequence 275 True
# AAC Extracted features for sequence 276 True
# AAC Extracted features for sequence 277 True
# AAC Extracted features for sequence 278 True
# AAC Extracted features for sequence 279 True
# AAC Extracted features for sequence 280 True
# AAC Extracted features for sequence 281 True
# AAC Extracted features for sequence 282 True
# AAC Extracted features for sequence 283 True
# AAC Extracted features for sequence 284 True
# AAC Extracted features for sequence 285 True
# AAC Extracted features for sequence 286 True
# AAC Extracted features for sequence 287 True
# AAC Extracted features for sequence 288 True
# AAC Extracted features for sequence 289 True
# AAC Extracted features for sequence 290 True
# AAC Extracted features for sequence 291 True
# AAC Extracted features for sequence 292 True
# AAC Extracted features for sequence 293 True
# AAC Extracted features for sequence 294 True
# AAC Extracted features for sequence 295 True
# AAC Extracted features for sequence 296 True
# AAC Extracted features for sequence 297 True
# AAC Extracted features for sequence 298 True
# AAC Extracted features for sequence 299 True
# AAC Extracted features for sequence 300 True
# AAC Extracted features for sequence 301 True
# AAC Extracted features for sequence 302 True
# AAC Extracted features for sequence 303 True
# AAC Extracted features for sequence 304 True
# AAC Extracted features for sequence 305 True
# AAC Extracted features for sequence 306 True
# AAC Extracted features for sequence 307 True
# AAC Extracted features for sequence 308 True
# AAC Extracted features for sequence 309 True
# AAC Extracted features for sequence 310 True
# AAC Extracted features for sequence 311 True
# AAC Extracted features for sequence 312 True
# AAC Extracted features for sequence 313 True
# AAC Extracted features for sequence 314 True
# AAC Extracted features for sequence 315 True
# AAC Extracted features for sequence 316 True
# AAC Extracted features for sequence 317 True
# AAC Extracted features for sequence 318 True
# AAC Extracted features for sequence 319 True
# AAC Extracted features for sequence 320 True
# AAC Extracted features for sequence 321 True
# AAC Extracted features for sequence 322 True
# AAC Extracted features for sequence 323 True
# AAC Extracted features for sequence 324 True
# AAC Extracted features for sequence 325 True
# AAC Extracted features for sequence 326 True
# AAC Extracted features for sequence 327 True
# AAC Extracted features for sequence 328 True
# AAC Extracted features for sequence 329 True
# AAC Extracted features for sequence 330 True
# AAC Extracted features for sequence 331 True
# AAC Extracted features for sequence 332 True
# AAC Extracted features for sequence 333 True
# AAC Extracted features for sequence 334 True
# AAC Extracted features for sequence 335 True
# AAC Extracted features for sequence 336 True
# AAC Extracted features for sequence 337 True
# AAC Extracted features for sequence 338 True
# AAC Extracted features for sequence 339 True
# AAC Extracted features for sequence 340 True
# AAC Extracted features for sequence 341 True
# AAC Extracted features for sequence 342 True
# AAC Extracted features for sequence 343 True
# AAC Extracted features for sequence 344 True
# AAC Extracted features for sequence 345 True
# AAC Extracted features for sequence 346 True
# AAC Extracted features for sequence 347 True
# AAC Extracted features for sequence 348 True
# AAC Extracted features for sequence 349 True
# AAC Extracted features for sequence 350 True
# AAC Extracted features for sequence 351 True
# AAC Extracted features for sequence 352 True
# AAC Extracted features for sequence 353 True
# AAC Extracted features for sequence 354 True
# AAC Extracted features for sequence 355 True
# AAC Extracted features for sequence 356 True
# AAC Extracted features for sequence 357 True
# AAC Extracted features for sequence 358 True
# AAC Extracted features for sequence 359 True
# AAC Extracted features for sequence 360 True
# AAC Extracted features for sequence 361 True
# AAC Extracted features for sequence 362 True
# AAC Extracted features for sequence 363 True
# AAC Extracted features for sequence 364 True
# AAC Extracted features for sequence 365 True
# AAC Extracted features for sequence 366 True
# AAC Extracted features for sequence 367 True
# AAC Extracted features for sequence 368 True
# AAC Extracted features for sequence 369 True
# AAC Extracted features for sequence 370 True
# AAC Extracted features for sequence 371 True
# AAC Extracted features for sequence 372 True
# AAC Extracted features for sequence 373 True
# AAC Extracted features for sequence 374 True
# AAC Extracted features for sequence 375 True
# AAC Extracted features for sequence 376 True
# AAC Extracted features for sequence 377 True
# AAC Extracted features for sequence 378 True
# AAC Extracted features for sequence 379 True
# AAC Extracted features for sequence 380 True
# AAC Extracted features for sequence 381 True
# AAC Extracted features for sequence 382 True
# AAC Extracted features for sequence 383 True
# AAC Extracted features for sequence 384 True
# AAC Extracted features for sequence 385 True
# AAC Extracted features for sequence 386 True
# AAC Extracted features for sequence 387 True
# AAC Extracted features for sequence 388 True
# AAC Extracted features for sequence 389 True
# AAC Extracted features for sequence 390 True
# AAC Extracted features for sequence 391 True
# AAC Extracted features for sequence 392 True
# AAC Extracted features for sequence 393 True
# AAC Extracted features for sequence 394 True
# AAC Extracted features for sequence 395 True
# AAC Extracted features for sequence 396 True
# AAC Extracted features for sequence 397 True
# AAC Extracted features for sequence 398 True
# AAC Extracted features for sequence 399 True
# AAC Extracted features for sequence 400 True
# AAC Extracted features for sequence 401 True
# AAC Extracted features for sequence 402 True
# AAC Extracted features for sequence 403 True
# AAC Extracted features for sequence 404 True
# AAC Extracted features for sequence 405 True
# AAC Extracted features for sequence 406 True
# AAC Extracted features for sequence 407 True
# AAC Extracted features for sequence 408 True
# AAC Extracted features for sequence 409 True
# AAC Extracted features for sequence 410 True
# AAC Extracted features for sequence 411 True
# AAC Extracted features for sequence 412 True
# AAC Extracted features for sequence 413 True
# AAC Extracted features for sequence 414 True
# AAC Extracted features for sequence 415 True
# AAC Extracted features for sequence 416 True
# AAC Extracted features for sequence 417 True
# AAC Extracted features for sequence 418 True
# AAC Extracted features for sequence 419 True
# AAC Extracted features for sequence 420 True
# AAC Extracted features for sequence 421 True
# AAC Extracted features for sequence 422 True
# AAC Extracted features for sequence 423 True
# AAC Extracted features for sequence 424 True
# AAC Extracted features for sequence 425 True
# AAC Extracted features for sequence 426 True
# AAC Extracted features for sequence 427 True
# AAC Extracted features for sequence 428 True
# AAC Extracted features for sequence 429 True
# AAC Extracted features for sequence 430 True
# AAC Extracted features for sequence 431 True
# AAC Extracted features for sequence 432 True
# AAC Extracted features for sequence 433 True
# AAC Extracted features for sequence 434 True
# AAC Extracted features for sequence 435 True
# AAC Extracted features for sequence 436 True
# AAC Extracted features for sequence 437 True
# AAC Extracted features for sequence 438 True
# AAC Extracted features for sequence 439 True
# AAC Extracted features for sequence 440 True
# AAC Extracted features for sequence 441 True
# AAC Extracted features for sequence 442 True
# AAC Extracted features for sequence 443 True
# AAC Extracted features for sequence 444 True
# AAC Extracted features for sequence 445 True
# AAC Extracted features for sequence 446 True
# AAC Extracted features for sequence 447 True
# AAC Extracted features for sequence 448 True
# AAC Extracted features for sequence 449 True
# AAC Extracted features for sequence 450 True
# AAC Extracted features for sequence 451 True
# AAC Extracted features for sequence 452 True
# AAC Extracted features for sequence 453 True
# AAC Extracted features for sequence 454 True
# AAC Extracted features for sequence 455 True
# AAC Extracted features for sequence 456 True
# AAC Extracted features for sequence 457 True
# AAC Extracted features for sequence 458 True
# AAC Extracted features for sequence 459 True
# AAC Extracted features for sequence 460 True
# AAC Extracted features for sequence 461 True
# AAC Extracted features for sequence 462 True
# AAC Extracted features for sequence 463 True
# AAC Extracted features for sequence 464 True
# AAC Extracted features for sequence 465 True
# AAC Extracted features for sequence 466 True
# AAC Extracted features for sequence 467 True
# AAC Extracted features for sequence 468 True
# AAC Extracted features for sequence 469 True
# AAC Extracted features for sequence 470 True
# AAC Extracted features for sequence 471 True
# AAC Extracted features for sequence 472 True
# AAC Extracted features for sequence 473 True
# AAC Extracted features for sequence 474 True
# AAC Extracted features for sequence 475 True
# AAC Extracted features for sequence 476 True
# AAC Extracted features for sequence 477 True
# AAC Extracted features for sequence 478 True
# AAC Extracted features for sequence 479 True
# AAC Extracted features for sequence 480 True
# AAC Extracted features for sequence 481 True
# AAC Extracted features for sequence 482 True
# AAC Extracted features for sequence 483 True
# AAC Extracted features for sequence 484 True
# AAC Extracted features for sequence 485 True
# AAC Extracted features for sequence 486 True
# AAC Extracted features for sequence 487 True
# AAC Extracted features for sequence 488 True
# AAC Extracted features for sequence 489 True
# AAC Extracted features for sequence 490 True
# AAC Extracted features for sequence 491 True
# AAC Extracted features for sequence 492 True
# AAC Extracted features for sequence 493 True
# AAC Extracted features for sequence 494 True
# AAC Extracted features for sequence 495 True
# AAC Extracted features for sequence 496 True
# AAC Extracted features for sequence 497 True
# AAC Extracted features for sequence 498 True
# AAC Extracted features for sequence 499 True
# AAC Extracted features for sequence 500 True
# AAC Extracted features for sequence 501 True
# AAC Extracted features for sequence 502 True
# AAC Extracted features for sequence 503 True
# AAC Extracted features for sequence 504 True
# AAC Extracted features for sequence 505 True
# AAC Extracted features for sequence 506 True
# AAC Extracted features for sequence 507 True
# AAC Extracted features for sequence 508 True
# AAC Extracted features for sequence 509 True
# AAC Extracted features for sequence 510 True
# AAC Extracted features for sequence 511 True
# AAC Extracted features for sequence 512 True
# AAC Extracted features for sequence 513 True
# AAC Extracted features for sequence 514 True
# AAC Extracted features for sequence 515 True
# AAC Extracted features for sequence 516 True
# AAC Extracted features for sequence 517 True
# AAC Extracted features for sequence 518 True
# AAC Extracted features for sequence 519 True
# AAC Extracted features for sequence 520 True
# AAC Extracted features for sequence 521 True
# AAC Extracted features for sequence 522 True
# AAC Extracted features for sequence 523 True
# AAC Extracted features for sequence 524 True
# AAC Extracted features for sequence 525 True
# AAC Extracted features for sequence 526 True
# AAC Extracted features for sequence 527 True
# AAC Extracted features for sequence 528 True
# AAC Extracted features for sequence 529 True
# AAC Extracted features for sequence 530 True
# AAC Extracted features for sequence 531 True
# AAC Extracted features for sequence 532 True
# AAC Extracted features for sequence 533 True
# AAC Extracted features for sequence 534 True
# AAC Extracted features for sequence 535 True
# AAC Extracted features for sequence 536 True
# AAC Extracted features for sequence 537 True
# AAC Extracted features for sequence 538 True
# AAC Extracted features for sequence 539 True
# AAC Extracted features for sequence 540 True
# AAC Extracted features for sequence 541 True
# AAC Extracted features for sequence 542 True
# AAC Extracted features for sequence 543 True
# AAC Extracted features for sequence 544 True
# AAC Extracted features for sequence 545 True
# AAC Extracted features for sequence 546 True
# AAC Extracted features for sequence 547 True
# AAC Extracted features for sequence 548 True
# AAC Extracted features for sequence 549 True
# AAC Extracted features for sequence 550 True
# AAC Extracted features for sequence 551 True
# AAC Extracted features for sequence 552 True
# AAC Extracted features for sequence 553 True
# AAC Extracted features for sequence 554 True
# AAC Extracted features for sequence 555 True
# AAC Extracted features for sequence 556 True
# AAC Extracted features for sequence 557 True
# AAC Extracted features for sequence 558 True
# AAC Extracted features for sequence 559 True
# AAC Extracted features for sequence 560 True
# AAC Extracted features for sequence 561 True
# AAC Extracted features for sequence 562 True
# AAC Extracted features for sequence 563 True
# AAC Extracted features for sequence 564 True
# AAC Extracted features for sequence 565 True
# AAC Extracted features for sequence 566 True
# AAC Extracted features for sequence 567 True
# AAC Extracted features for sequence 568 True
# AAC Extracted features for sequence 569 True
# AAC Extracted features for sequence 570 True
# AAC Extracted features for sequence 571 True
# AAC Extracted features for sequence 572 True
# AAC Extracted features for sequence 573 True
# AAC Extracted features for sequence 574 True
# AAC Extracted features for sequence 575 True
# AAC Extracted features for sequence 576 True
# AAC Extracted features for sequence 577 True
# AAC Extracted features for sequence 578 True
# AAC Extracted features for sequence 579 True
# AAC Extracted features for sequence 580 True
# AAC Extracted features for sequence 581 True
# AAC Extracted features for sequence 582 True
# AAC Extracted features for sequence 583 True
# AAC Extracted features for sequence 584 True
# AAC Extracted features for sequence 585 True
# AAC Extracted features for sequence 586 True
# AAC Extracted features for sequence 587 True
# AAC Extracted features for sequence 588 True
# AAC Extracted features for sequence 589 True
# AAC Extracted features for sequence 590 True
# AAC Extracted features for sequence 591 True
# AAC Extracted features for sequence 592 True
# AAC Extracted features for sequence 593 True
# AAC Extracted features for sequence 594 True
# AAC Extracted features for sequence 595 True
# AAC Extracted features for sequence 596 True
# AAC Extracted features for sequence 597 True
# AAC Extracted features for sequence 598 True
# AAC Extracted features for sequence 599 True
# AAC Extracted features for sequence 600 True
# AAC Extracted features for sequence 601 True
# AAC Extracted features for sequence 602 True
# AAC Extracted features for sequence 603 True
# AAC Extracted features for sequence 604 True
# AAC Extracted features for sequence 605 True
# AAC Extracted features for sequence 606 True
# AAC Extracted features for sequence 607 True
# AAC Extracted features for sequence 608 True
# AAC Extracted features for sequence 609 True
# AAC Extracted features for sequence 610 True
# AAC Extracted features for sequence 611 True
# AAC Extracted features for sequence 612 True
# AAC Extracted features for sequence 613 True
# AAC Extracted features for sequence 614 True
# AAC Extracted features for sequence 615 True
# AAC Extracted features for sequence 616 True
# AAC Extracted features for sequence 617 True
# AAC Extracted features for sequence 618 True
# AAC Extracted features for sequence 619 True
# AAC Extracted features for sequence 620 True
# AAC Extracted features for sequence 621 True
# AAC Extracted features for sequence 622 True
# AAC Extracted features for sequence 623 True
# AAC Extracted features for sequence 624 True
# AAC Extracted features for sequence 625 True
# AAC Extracted features for sequence 626 True
# AAC Extracted features for sequence 627 True
# AAC Extracted features for sequence 628 True
# AAC Extracted features for sequence 629 True
# AAC Extracted features for sequence 630 True
# AAC Extracted features for sequence 631 True
# AAC Extracted features for sequence 632 True
# AAC Extracted features for sequence 633 True
# AAC Extracted features for sequence 634 True
# AAC Extracted features for sequence 635 True
# AAC Extracted features for sequence 636 True
# AAC Extracted features for sequence 637 True
# AAC Extracted features for sequence 638 True
# AAC Extracted features for sequence 639 True
# AAC Extracted features for sequence 640 True
# AAC Extracted features for sequence 641 True
# AAC Extracted features for sequence 642 True
# AAC Extracted features for sequence 643 True
# AAC Extracted features for sequence 644 True
# AAC Extracted features for sequence 645 True
# AAC Extracted features for sequence 646 True
# AAC Extracted features for sequence 647 True
# AAC Extracted features for sequence 648 True
# AAC Extracted features for sequence 649 True
# AAC Extracted features for sequence 650 True
# AAC Extracted features for sequence 651 True
# AAC Extracted features for sequence 652 True
# AAC Extracted features for sequence 653 True
# AAC Extracted features for sequence 654 True
# AAC Extracted features for sequence 655 True
# AAC Extracted features for sequence 656 True
# AAC Extracted features for sequence 657 True
# AAC Extracted features for sequence 658 True
# AAC Extracted features for sequence 659 True
# AAC Extracted features for sequence 660 True
# AAC Extracted features for sequence 661 True
# AAC Extracted features for sequence 662 True
# AAC Extracted features for sequence 663 True
# AAC Extracted features for sequence 664 True
# AAC Extracted features for sequence 665 True
# AAC Extracted features for sequence 666 True
# AAC Extracted features for sequence 667 True
# AAC Extracted features for sequence 668 True
# AAC Extracted features for sequence 669 True
# AAC Extracted features for sequence 670 True
# AAC Extracted features for sequence 671 True
# AAC Extracted features for sequence 672 True
# AAC Extracted features for sequence 673 True
# AAC Extracted features for sequence 674 True
# AAC Extracted features for sequence 675 True
# AAC Extracted features for sequence 676 True
# AAC Extracted features for sequence 677 True
# AAC Extracted features for sequence 678 True
# AAC Extracted features for sequence 679 True
# AAC Extracted features for sequence 680 True
# AAC Extracted features for sequence 681 True
# AAC Extracted features for sequence 682 True
# AAC Extracted features for sequence 683 True
# AAC Extracted features for sequence 684 True
# AAC Extracted features for sequence 685 True
# AAC Extracted features for sequence 686 True
# AAC Extracted features for sequence 687 True
# AAC Extracted features for sequence 688 True
# AAC Extracted features for sequence 689 True
# AAC Extracted features for sequence 690 True
# AAC Extracted features for sequence 691 True
# AAC Extracted features for sequence 692 True
# AAC Extracted features for sequence 693 True
# AAC Extracted features for sequence 694 True
# AAC Extracted features for sequence 695 True
# AAC Extracted features for sequence 696 True
# AAC Extracted features for sequence 697 True
# AAC Extracted features for sequence 698 True
# AAC Extracted features for sequence 699 True
# AAC Extracted features for sequence 700 True
# AAC Extracted features for sequence 701 True
# AAC Extracted features for sequence 702 True
# AAC Extracted features for sequence 703 True
# AAC Extracted features for sequence 704 True
# AAC Extracted features for sequence 705 True
# AAC Extracted features for sequence 706 True
# AAC Extracted features for sequence 707 True
# AAC Extracted features for sequence 708 True
# AAC Extracted features for sequence 709 True
# AAC Extracted features for sequence 710 True
# AAC Extracted features for sequence 711 True
# AAC Extracted features for sequence 712 True
# AAC Extracted features for sequence 713 True
# AAC Extracted features for sequence 714 True
# AAC Extracted features for sequence 715 True
# AAC Extracted features for sequence 716 True
# AAC Extracted features for sequence 717 True
# AAC Extracted features for sequence 718 True
# AAC Extracted features for sequence 719 True
# AAC Extracted features for sequence 720 True
# AAC Extracted features for sequence 721 True
# AAC Extracted features for sequence 722 True
# AAC Extracted features for sequence 723 True
# AAC Extracted features for sequence 724 True
# AAC Extracted features for sequence 725 True
# AAC Extracted features for sequence 726 True
# AAC Extracted features for sequence 727 True
# AAC Extracted features for sequence 728 True
# AAC Extracted features for sequence 729 True
# AAC Extracted features for sequence 730 True
# AAC Extracted features for sequence 731 True
# AAC Extracted features for sequence 732 True
# AAC Extracted features for sequence 733 True
# AAC Extracted features for sequence 734 True
# AAC Extracted features for sequence 735 True
# AAC Extracted features for sequence 736 True
# AAC Extracted features for sequence 737 True
# AAC Extracted features for sequence 738 True
# AAC Extracted features for sequence 739 True
# AAC Extracted features for sequence 740 True
# AAC Extracted features for sequence 741 True
# AAC Extracted features for sequence 742 True
# AAC Extracted features for sequence 743 True
# AAC Extracted features for sequence 744 True
# AAC Extracted features for sequence 745 True
# AAC Extracted features for sequence 746 True
# AAC Extracted features for sequence 747 True
# AAC Extracted features for sequence 748 True
# AAC Extracted features for sequence 749 True
# AAC Extracted features for sequence 750 True
# AAC Extracted features for sequence 751 True
# AAC Extracted features for sequence 752 True
# AAC Extracted features for sequence 753 True
# AAC Extracted features for sequence 754 True
# AAC Extracted features for sequence 755 True
# AAC Extracted features for sequence 756 True
# AAC Extracted features for sequence 757 True
# AAC Extracted features for sequence 758 True
# AAC Extracted features for sequence 759 True
# AAC Extracted features for sequence 760 True
# AAC Extracted features for sequence 761 True
# AAC Extracted features for sequence 762 True
# AAC Extracted features for sequence 763 True
# AAC Extracted features for sequence 764 True
# AAC Extracted features for sequence 765 True
# AAC Extracted features for sequence 766 True
# AAC Extracted features for sequence 767 True
# AAC Extracted features for sequence 768 True
# AAC Extracted features for sequence 769 True
# AAC Extracted features for sequence 770 True
# AAC Extracted features for sequence 771 True
# AAC Extracted features for sequence 772 True
# AAC Extracted features for sequence 773 True
# AAC Extracted features for sequence 774 True
# AAC Extracted features for sequence 775 True
# AAC Extracted features for sequence 776 True
# AAC Extracted features for sequence 777 True
# AAC Extracted features for sequence 778 True
# AAC Extracted features for sequence 779 True
# AAC Extracted features for sequence 780 True
# AAC Extracted features for sequence 781 True
# AAC Extracted features for sequence 782 True
# AAC Extracted features for sequence 783 True
# AAC Extracted features for sequence 784 True
# AAC Extracted features for sequence 785 True
# AAC Extracted features for sequence 786 True
# AAC Extracted features for sequence 787 True
# AAC Extracted features for sequence 788 True
# AAC Extracted features for sequence 789 True
# AAC Extracted features for sequence 790 True
# AAC Extracted features for sequence 791 True
# AAC Extracted features for sequence 792 True
# AAC Extracted features for sequence 793 True
# AAC Extracted features for sequence 794 True
# AAC Extracted features for sequence 795 True
# AAC Extracted features for sequence 796 True
# AAC Extracted features for sequence 797 True
# AAC Extracted features for sequence 798 True
# AAC Extracted features for sequence 799 True
# AAC Extracted features for sequence 800 True
# AAC Extracted features for sequence 801 True
# AAC Extracted features for sequence 802 True
# AAC Extracted features for sequence 803 True
# AAC Extracted features for sequence 804 True
# AAC Extracted features for sequence 805 True
# AAC Extracted features for sequence 806 True
# AAC Extracted features for sequence 807 True
# AAC Extracted features for sequence 808 True
# AAC Extracted features for sequence 809 True
# AAC Extracted features for sequence 810 True
# AAC Extracted features for sequence 811 True
# AAC Extracted features for sequence 812 True
# AAC Extracted features for sequence 813 True
# AAC Extracted features for sequence 814 True
# AAC Extracted features for sequence 815 True
# AAC Extracted features for sequence 816 True
# AAC Extracted features for sequence 817 True
# AAC Extracted features for sequence 818 True
# AAC Extracted features for sequence 819 True
# AAC Extracted features for sequence 820 True
# AAC Extracted features for sequence 821 True
# AAC Extracted features for sequence 822 True
# AAC Extracted features for sequence 823 True
# AAC Extracted features for sequence 824 True
# AAC Extracted features for sequence 825 True
# AAC Extracted features for sequence 826 True
# AAC Extracted features for sequence 827 True
# AAC Extracted features for sequence 828 True
# AAC Extracted features for sequence 829 True
# AAC Extracted features for sequence 830 True
# AAC Extracted features for sequence 831 True
# AAC Extracted features for sequence 832 True
# AAC Extracted features for sequence 833 True
# AAC Extracted features for sequence 834 True
# AAC Extracted features for sequence 835 True
# AAC Extracted features for sequence 836 True
# AAC Extracted features for sequence 837 True
# AAC Extracted features for sequence 838 True
# AAC Extracted features for sequence 839 True
# AAC Extracted features for sequence 840 True
# AAC Extracted features for sequence 841 True
# AAC Extracted features for sequence 842 True
# AAC Extracted features for sequence 843 True
# AAC Extracted features for sequence 844 True
# AAC Extracted features for sequence 845 True
# AAC Extracted features for sequence 846 True
# AAC Extracted features for sequence 847 True
# AAC Extracted features for sequence 848 True
# AAC Extracted features for sequence 849 True
# AAC Extracted features for sequence 850 True
# AAC Extracted features for sequence 851 True
# AAC Extracted features for sequence 852 True
# AAC Extracted features for sequence 853 True
# AAC Extracted features for sequence 854 True
# AAC Extracted features for sequence 855 True
# AAC Extracted features for sequence 856 True
# AAC Extracted features for sequence 857 True
# AAC Extracted features for sequence 858 True
# AAC Extracted features for sequence 859 True
# AAC Extracted features for sequence 860 True
# AAC Extracted features for sequence 861 True
# AAC Extracted features for sequence 862 True
# AAC Extracted features for sequence 863 True
# AAC Extracted features for sequence 864 True
# AAC Extracted features for sequence 865 True
# AAC Extracted features for sequence 866 True
# AAC Extracted features for sequence 867 True
# AAC Extracted features for sequence 868 True
# AAC Extracted features for sequence 869 True
# AAC Extracted features for sequence 870 True
# AAC Extracted features for sequence 871 True
# AAC Extracted features for sequence 872 True
# AAC Extracted features for sequence 873 True
# AAC Extracted features for sequence 874 True
# AAC Extracted features for sequence 875 True
# AAC Extracted features for sequence 876 True
# AAC Extracted features for sequence 877 True
# AAC Extracted features for sequence 878 True
# AAC Extracted features for sequence 879 True
# AAC Extracted features for sequence 880 True
# AAC Extracted features for sequence 881 True
# AAC Extracted features for sequence 882 True
# AAC Extracted features for sequence 883 True
# AAC Extracted features for sequence 884 True
# AAC Extracted features for sequence 885 True
# AAC Extracted features for sequence 886 True
# AAC Extracted features for sequence 887 True
# AAC Extracted features for sequence 888 True
# AAC Extracted features for sequence 889 True
# AAC Extracted features for sequence 890 True
# AAC Extracted features for sequence 891 True
# AAC Extracted features for sequence 892 True
# AAC Extracted features for sequence 893 True
# AAC Extracted features for sequence 894 True
# AAC Extracted features for sequence 895 True
# AAC Extracted features for sequence 896 True
# AAC Extracted features for sequence 897 True
# AAC Extracted features for sequence 898 True
# AAC Extracted features for sequence 899 True
# AAC Extracted features for sequence 900 True
# AAC Extracted features for sequence 901 True
# AAC Extracted features for sequence 902 True
# AAC Extracted features for sequence 903 True
# AAC Extracted features for sequence 904 True
# AAC Extracted features for sequence 905 True
# AAC Extracted features for sequence 906 True
# AAC Extracted features for sequence 907 True
# AAC Extracted features for sequence 908 True
# AAC Extracted features for sequence 909 True
# AAC Extracted features for sequence 910 True
# AAC Extracted features for sequence 911 True
# AAC Extracted features for sequence 912 True
# AAC Extracted features for sequence 913 True
# AAC Extracted features for sequence 914 True
# AAC Extracted features for sequence 915 True
# AAC Extracted features for sequence 916 True
# AAC Extracted features for sequence 917 True
# AAC Extracted features for sequence 918 True
# AAC Extracted features for sequence 919 True
# AAC Extracted features for sequence 920 True
# AAC Extracted features for sequence 921 True
# AAC Extracted features for sequence 922 True
# AAC Extracted features for sequence 923 True
# AAC Extracted features for sequence 924 True
# AAC Extracted features for sequence 925 True
# AAC Extracted features for sequence 926 True
# AAC Extracted features for sequence 927 True
# AAC Extracted features for sequence 928 True
# AAC Extracted features for sequence 929 True
# AAC Extracted features for sequence 930 True
# AAC Extracted features for sequence 931 True
# AAC Extracted features for sequence 932 True
# AAC Extracted features for sequence 933 True
# AAC Extracted features for sequence 934 True
# AAC Extracted features for sequence 935 True
# AAC Extracted features for sequence 936 True
# AAC Extracted features for sequence 937 True
# AAC Extracted features for sequence 938 True
# AAC Extracted features for sequence 939 True
# AAC Extracted features for sequence 940 True
# AAC Extracted features for sequence 941 True
# AAC Extracted features for sequence 942 True
# AAC Extracted features for sequence 943 True
# AAC Extracted features for sequence 944 True
# AAC Extracted features for sequence 945 True
# AAC Extracted features for sequence 946 True
# AAC Extracted features for sequence 947 True
# AAC Extracted features for sequence 948 True
# AAC Extracted features for sequence 949 True
# AAC Extracted features for sequence 950 True
# AAC Extracted features for sequence 951 True
# AAC Extracted features for sequence 952 True
# AAC Extracted features for sequence 953 True
# AAC Extracted features for sequence 954 True
# AAC Extracted features for sequence 955 True
# AAC Extracted features for sequence 956 True
# AAC Extracted features for sequence 957 True
# AAC Extracted features for sequence 958 True
# AAC Extracted features for sequence 959 True
# AAC Extracted features for sequence 960 True
# AAC Extracted features for sequence 961 True
# AAC Extracted features for sequence 962 True
# AAC Extracted features for sequence 963 True
# AAC Extracted features for sequence 964 True
# AAC Extracted features for sequence 965 True
# AAC Extracted features for sequence 966 True
# AAC Extracted features for sequence 967 True
# AAC Extracted features for sequence 968 True
# AAC Extracted features for sequence 969 True
# AAC Extracted features for sequence 970 True
# AAC Extracted features for sequence 971 True
# AAC Extracted features for sequence 972 True
# AAC Extracted features for sequence 973 True
# AAC Extracted features for sequence 974 True
# AAC Extracted features for sequence 975 True
# AAC Extracted features for sequence 976 True
# AAC Extracted features for sequence 977 True
# AAC Extracted features for sequence 978 True
# AAC Extracted features for sequence 979 True
# AAC Extracted features for sequence 980 True
# AAC Extracted features for sequence 981 True
# AAC Extracted features for sequence 982 True
# AAC Extracted features for sequence 983 True
# AAC Extracted features for sequence 984 True
# AAC Extracted features for sequence 985 True
# AAC Extracted features for sequence 986 True
# AAC Extracted features for sequence 987 True
# AAC Extracted features for sequence 988 True
# AAC Extracted features for sequence 989 True
# AAC Extracted features for sequence 990 True
# AAC Extracted features for sequence 991 True
# AAC Extracted features for sequence 992 True
# AAC Extracted features for sequence 993 True
# AAC Extracted features for sequence 994 True
# AAC Extracted features for sequence 995 True
# AAC Extracted features for sequence 996 True
# AAC Extracted features for sequence 997 True
# AAC Extracted features for sequence 998 True
# AAC Extracted features for sequence 999 True
# AAC Extracted features for sequence 1000 True
# AAC Extracted features for sequence 1001 True
# AAC Extracted features for sequence 1002 True
# AAC Extracted features for sequence 1003 True
# AAC Extracted features for sequence 1004 True
# AAC Extracted features for sequence 1005 True
# AAC Extracted features for sequence 1006 True
# AAC Extracted features for sequence 1007 True
# AAC Extracted features for sequence 1008 True
# AAC Extracted features for sequence 1009 True
# AAC Extracted features for sequence 1010 True
# AAC Extracted features for sequence 1011 True
# AAC Extracted features for sequence 1012 True
# AAC Extracted features for sequence 1013 True
# AAC Extracted features for sequence 1014 True
# AAC Extracted features for sequence 1015 True
# AAC Extracted features for sequence 1016 True
# AAC Extracted features for sequence 1017 True
# AAC Extracted features for sequence 1018 True
# AAC Extracted features for sequence 1019 True
# AAC Extracted features for sequence 1020 True
# AAC Extracted features for sequence 1021 True
# AAC Extracted features for sequence 1022 True
# AAC Extracted features for sequence 1023 True
# AAC Extracted features for sequence 1024 True
# AAC Extracted features for sequence 1025 True
# AAC Extracted features for sequence 1026 True
# AAC Extracted features for sequence 1027 True
# AAC Extracted features for sequence 1028 True
# AAC Extracted features for sequence 1029 True
# AAC Extracted features for sequence 1030 True
# AAC Extracted features for sequence 1031 True
# AAC Extracted features for sequence 1032 True
# AAC Extracted features for sequence 1033 True
# AAC Extracted features for sequence 1034 True
# AAC Extracted features for sequence 1035 True
# AAC Extracted features for sequence 1036 True
# AAC Extracted features for sequence 1037 True
# AAC Extracted features for sequence 1038 True
# AAC Extracted features for sequence 1039 True
# AAC Extracted features for sequence 1040 True
# AAC Extracted features for sequence 1041 True
# AAC Extracted features for sequence 1042 True
# AAC Extracted features for sequence 1043 True
# AAC Extracted features for sequence 1044 True
# AAC Extracted features for sequence 1045 True
# AAC Extracted features for sequence 1046 True
# AAC Extracted features for sequence 1047 True
# AAC Extracted features for sequence 1048 True
# AAC Extracted features for sequence 1049 True
# AAC Extracted features for sequence 1050 True
# AAC Extracted features for sequence 1051 True
# AAC Extracted features for sequence 1052 True
# AAC Extracted features for sequence 1053 True
# AAC Extracted features for sequence 1054 True
# AAC Extracted features for sequence 1055 True
# AAC Extracted features for sequence 1056 True
# AAC Extracted features for sequence 1057 True
# AAC Extracted features for sequence 1058 True
# AAC Extracted features for sequence 1059 True
# AAC Extracted features for sequence 1060 True
# AAC Extracted features for sequence 1061 True
# AAC Extracted features for sequence 1062 True
# AAC Extracted features for sequence 1063 True
# AAC Extracted features for sequence 1064 True
# AAC Extracted features for sequence 1065 True
# AAC Extracted features for sequence 1066 True
# ...
# DPC Extracted features for sequence 881 False
# DPC Extracted features for sequence 882 False
# DPC Extracted features for sequence 883 False
# DPC Extracted features for sequence 884 False
# DPC Extracted features for sequence 885 False
# DPC Extracted features for sequence 886 False
# DPC Extracted features for sequence 887 False
# DPC Extracted features for sequence 888 False
# DPC Extracted features for sequence 889 False
# DPC Extracted features for sequence 890 False
# DPC Extracted features for sequence 891 False
# DPC Extracted features for sequence 892 False
# DPC Extracted features for sequence 893 False
# DPC Extracted features for sequence 894 False
# DPC Extracted features for sequence 895 False
# DPC Extracted features for sequence 896 False
# DPC Extracted features for sequence 897 False
# DPC Extracted features for sequence 898 False
# DPC Extracted features for sequence 899 False
# DPC Extracted features for sequence 900 False
# DPC Extracted features for sequence 901 False
# DPC Extracted features for sequence 902 False
# DPC Extracted features for sequence 903 False
# DPC Extracted features for sequence 904 False
# DPC Extracted features for sequence 905 False
# DPC Extracted features for sequence 906 False
# DPC Extracted features for sequence 907 False
# DPC Extracted features for sequence 908 False
# DPC Extracted features for sequence 909 False
# DPC Extracted features for sequence 910 False
# DPC Extracted features for sequence 911 False
# DPC Extracted features for sequence 912 False
# DPC Extracted features for sequence 913 False
# DPC Extracted features for sequence 914 False
# DPC Extracted features for sequence 915 False
# DPC Extracted features for sequence 916 False
# DPC Extracted features for sequence 917 False
# DPC Extracted features for sequence 918 False
# DPC Extracted features for sequence 919 False
# DPC Extracted features for sequence 920 False
# DPC Extracted features for sequence 921 False
# DPC Extracted features for sequence 922 False
# DPC Extracted features for sequence 923 False
# DPC Extracted features for sequence 924 False
# DPC Extracted features for sequence 925 False
# DPC Extracted features for sequence 926 False
# DPC Extracted features for sequence 927 False
# DPC Extracted features for sequence 928 False
# DPC Extracted features for sequence 929 False
# DPC Extracted features for sequence 930 False
# DPC Extracted features for sequence 931 False
# DPC Extracted features for sequence 932 False
# DPC Extracted features for sequence 933 False
# DPC Extracted features for sequence 934 False
# DPC Extracted features for sequence 935 False
# DPC Extracted features for sequence 936 False
# DPC Extracted features for sequence 937 False
# DPC Extracted features for sequence 938 False
# DPC Extracted features for sequence 939 False
# DPC Extracted features for sequence 940 False
# DPC Extracted features for sequence 941 False
# DPC Extracted features for sequence 942 False
# DPC Extracted features for sequence 943 False
# DPC Extracted features for sequence 944 False
# DPC Extracted features for sequence 945 False
# DPC Extracted features for sequence 946 False
# DPC Extracted features for sequence 947 False
# DPC Extracted features for sequence 948 False
# DPC Extracted features for sequence 949 False
# DPC Extracted features for sequence 950 False
# DPC Extracted features for sequence 951 False
# DPC Extracted features for sequence 952 False
# DPC Extracted features for sequence 953 False
# DPC Extracted features for sequence 954 False
# DPC Extracted features for sequence 955 False
# DPC Extracted features for sequence 956 False
# DPC Extracted features for sequence 957 False
# DPC Extracted features for sequence 958 False
# DPC Extracted features for sequence 959 False
# DPC Extracted features for sequence 960 False
# DPC Extracted features for sequence 961 False
# DPC Extracted features for sequence 962 False
# DPC Extracted features for sequence 963 False
# DPC Extracted features for sequence 964 False
# DPC Extracted features for sequence 965 False
# DPC Extracted features for sequence 966 False
# DPC Extracted features for sequence 967 False
# DPC Extracted features for sequence 968 False
# DPC Extracted features for sequence 969 False
# DPC Extracted features for sequence 970 False
# DPC Extracted features for sequence 971 False
# DPC Extracted features for sequence 972 False
# DPC Extracted features for sequence 973 False
# DPC Extracted features for sequence 974 False
# DPC Extracted features for sequence 975 False
# DPC Extracted features for sequence 976 False
# DPC Extracted features for sequence 977 False
# DPC Extracted features for sequence 978 False
# DPC Extracted features for sequence 979 False
# DPC Extracted features for sequence 980 False
# DPC Extracted features for sequence 981 False
# DPC Extracted features for sequence 982 False
# DPC Extracted features for sequence 983 False
# DPC Extracted features for sequence 984 False
# DPC Extracted features for sequence 985 False
# DPC Extracted features for sequence 986 False
# DPC Extracted features for sequence 987 False
# DPC Extracted features for sequence 988 False
# DPC Extracted features for sequence 989 False
# DPC Extracted features for sequence 990 False
# DPC Extracted features for sequence 991 False
# DPC Extracted features for sequence 992 False
# DPC Extracted features for sequence 993 False
# DPC Extracted features for sequence 994 False
# DPC Extracted features for sequence 995 False
# DPC Extracted features for sequence 996 False
# DPC Extracted features for sequence 997 False
# DPC Extracted features for sequence 998 False
# DPC Extracted features for sequence 999 False
# DPC Extracted features for sequence 1000 False
# DPC Extracted features for sequence 1001 False
# DPC Extracted features for sequence 1002 False
# DPC Extracted features for sequence 1003 False
# DPC Extracted features for sequence 1004 False
# DPC Extracted features for sequence 1005 False
# DPC Extracted features for sequence 1006 False
# DPC Extracted features for sequence 1007 False
# DPC Extracted features for sequence 1008 False
# DPC Extracted features for sequence 1009 False
# DPC Extracted features for sequence 1010 False
# DPC Extracted features for sequence 1011 False
# DPC Extracted features for sequence 1012 False
# DPC Extracted features for sequence 1013 False
# DPC Extracted features for sequence 1014 False
# DPC Extracted features for sequence 1015 False
# DPC Extracted features for sequence 1016 False
# DPC Extracted features for sequence 1017 False
# DPC Extracted features for sequence 1018 False
# DPC Extracted features for sequence 1019 False
# DPC Extracted features for sequence 1020 False
# DPC Extracted features for sequence 1021 False
# DPC Extracted features for sequence 1022 False
# DPC Extracted features for sequence 1023 False
# DPC Extracted features for sequence 1024 False
# DPC Extracted features for sequence 1025 False
# DPC Extracted features for sequence 1026 False
# DPC Extracted features for sequence 1027 False
# DPC Extracted features for sequence 1028 False
# DPC Extracted features for sequence 1029 False
# DPC Extracted features for sequence 1030 False
# DPC Extracted features for sequence 1031 False
# DPC Extracted features for sequence 1032 False
# DPC Extracted features for sequence 1033 False
# DPC Extracted features for sequence 1034 False
# DPC Extracted features for sequence 1035 False
# DPC Extracted features for sequence 1036 False
# DPC Extracted features for sequence 1037 False
# DPC Extracted features for sequence 1038 False
# DPC Extracted features for sequence 1039 False
# DPC Extracted features for sequence 1040 False
# DPC Extracted features for sequence 1041 False
# DPC Extracted features for sequence 1042 False
# DPC Extracted features for sequence 1043 False
# DPC Extracted features for sequence 1044 False
# DPC Extracted features for sequence 1045 False
# DPC Extracted features for sequence 1046 False
# DPC Extracted features for sequence 1047 False
# DPC Extracted features for sequence 1048 False
# DPC Extracted features for sequence 1049 False
# DPC Extracted features for sequence 1050 False
# DPC Extracted features for sequence 1051 False
# DPC Extracted features for sequence 1052 False
# DPC Extracted features for sequence 1053 False
# DPC Extracted features for sequence 1054 False
# DPC Extracted features for sequence 1055 False
# DPC Extracted features for sequence 1056 False
# DPC Extracted features for sequence 1057 False
# DPC Extracted features for sequence 1058 False
# DPC Extracted features for sequence 1059 False
# DPC Extracted features for sequence 1060 False
# DPC Extracted features for sequence 1061 False
# DPC Extracted features for sequence 1062 False
# DPC Extracted features for sequence 1063 False
# DPC Extracted features for sequence 1064 False
# DPC Extracted features for sequence 1065 False
# DPC Extracted features for sequence 1066 False
# DPC Extracted features for sequence 1067 False
# DPC Extracted features for sequence 1068 False
# DPC Extracted features for sequence 1069 False
# DPC Extracted features for sequence 1070 False
# DPC Extracted features for sequence 1071 False
# DPC Extracted features for sequence 1072 False
# DPC Extracted features for sequence 1073 False
# DPC Extracted features for sequence 1074 False
# DPC Extracted features for sequence 1075 False
# DPC Extracted features for sequence 1076 False
# DPC Extracted features for sequence 1077 False
# DPC Extracted features for sequence 1078 False
# DPC Extracted features for sequence 1079 False
# DPC Extracted features for sequence 1080 False
# DPC Extracted features for sequence 1081 False
# DPC Extracted features for sequence 1082 False
# DPC Extracted features for sequence 1083 False
# DPC Extracted features for sequence 1084 False
# DPC Extracted features for sequence 1085 False
# DPC Extracted features for sequence 1086 False
# DPC Extracted features for sequence 1087 False
# DPC Extracted features for sequence 1088 False
# DPC Extracted features for sequence 1089 False
# DPC Extracted features for sequence 1090 False
# DPC Extracted features for sequence 1091 False
# DPC Extracted features for sequence 1092 False
# DPC Extracted features for sequence 1093 False
# DPC Extracted features for sequence 1094 False
# DPC Extracted features for sequence 1095 False
# DPC Extracted features for sequence 1096 False
# DPC Extracted features for sequence 1097 False
# DPC Extracted features for sequence 1098 False
# DPC Extracted features for sequence 1099 False
# DPC Extracted features for sequence 1100 False
# DPC Extracted features for sequence 1101 False
# DPC Extracted features for sequence 1102 False
# DPC Extracted features for sequence 1103 False
# DPC Extracted features for sequence 1104 False
# DPC Extracted features for sequence 1105 False
# DPC Extracted features for sequence 1106 False
# DPC Extracted features for sequence 1107 False
# DPC Extracted features for sequence 1108 False
# DPC Extracted features for sequence 1109 False
# DPC Extracted features for sequence 1110 False
# DPC Extracted features for sequence 1111 False
# DPC Extracted features for sequence 1112 False
# DPC Extracted features for sequence 1113 False
# DPC Extracted features for sequence 1114 False
# DPC Extracted features for sequence 1115 False
# DPC Extracted features for sequence 1116 False
# DPC Extracted features for sequence 1117 False
# DPC Extracted features for sequence 1118 False
# DPC Extracted features for sequence 1119 False
# DPC Extracted features for sequence 1120 False
# DPC Extracted features for sequence 1121 False
# DPC Extracted features for sequence 1122 False
# DPC Extracted features for sequence 1123 False
# DPC Extracted features for sequence 1124 False
# DPC Extracted features for sequence 1125 False
# DPC Extracted features for sequence 1126 False
# DPC Extracted features for sequence 1127 False
# DPC Extracted features for sequence 1128 False
# DPC Extracted features for sequence 1129 False
# DPC Extracted features for sequence 1130 False
# DPC Extracted features for sequence 1131 False
# DPC Extracted features for sequence 1132 False
# DPC Extracted features for sequence 1133 False
# DPC Extracted features for sequence 1134 False
# DPC Extracted features for sequence 1135 False
# DPC Extracted features for sequence 1136 False
# DPC Extracted features for sequence 1137 False
# DPC Extracted features for sequence 1138 False
# DPC Extracted features for sequence 1139 False
# DPC Extracted features for sequence 1140 False
# DPC Extracted features for sequence 1141 False
# DPC Extracted features for sequence 1142 False
# DPC Extracted features for sequence 1143 False
# DPC Extracted features for sequence 1144 False
# DPC Extracted features for sequence 1145 False
# DPC Extracted features for sequence 1146 False
# DPC Extracted features for sequence 1147 False
# DPC Extracted features for sequence 1148 False
# DPC Extracted features for sequence 1149 False
# DPC Extracted features for sequence 1150 False
# DPC Extracted features for sequence 1151 False
# DPC Extracted features for sequence 1152 False
# DPC Extracted features for sequence 1153 False
# DPC Extracted features for sequence 1154 False
# DPC Extracted features for sequence 1155 False
# DPC Extracted features for sequence 1156 False
# DPC Extracted features for sequence 1157 False
# DPC Extracted features for sequence 1158 False
# DPC Extracted features for sequence 1159 False
# DPC Extracted features for sequence 1160 False
# DPC Extracted features for sequence 1161 False
# DPC Extracted features for sequence 1162 False
# DPC Extracted features for sequence 1163 False
# DPC Extracted features for sequence 1164 False
# DPC Extracted features for sequence 1165 False
# DPC Extracted features for sequence 1166 False
# DPC Extracted features for sequence 1167 False
# DPC Extracted features for sequence 1168 False
# DPC Extracted features for sequence 1169 False
# DPC Extracted features for sequence 1170 False
# DPC Extracted features for sequence 1171 False
# DPC Extracted features for sequence 1172 False
# DPC Extracted features for sequence 1173 False
# DPC Extracted features for sequence 1174 False
# DPC Extracted features for sequence 1175 False
# DPC Extracted features for sequence 1176 False
# DPC Extracted features for sequence 1177 False
# DPC Extracted features for sequence 1178 False
# DPC Extracted features for sequence 1179 False
# DPC Extracted features for sequence 1180 False
# DPC Extracted features for sequence 1181 False
# DPC Extracted features for sequence 1182 False
# DPC Extracted features for sequence 1183 False
# DPC Extracted features for sequence 1184 False
# DPC Extracted features for sequence 1185 False
# DPC Extracted features for sequence 1186 False
# DPC Extracted features for sequence 1187 False
# DPC Extracted features for sequence 1188 False
# DPC Extracted features for sequence 1189 False
# DPC Extracted features for sequence 1190 False
# DPC Extracted features for sequence 1191 False
# DPC Extracted features for sequence 1192 False
# DPC Extracted features for sequence 1193 False
# DPC Extracted features for sequence 1194 False
# DPC Extracted features for sequence 1195 False
# DPC Extracted features for sequence 1196 False
# DPC Extracted features for sequence 1197 False
# DPC Extracted features for sequence 1198 False
# DPC Extracted features for sequence 1199 False
# DPC Extracted features for sequence 1200 False
# DPC Extracted features for sequence 1201 False
# DPC Extracted features for sequence 1202 False
# DPC Extracted features for sequence 1203 False
# DPC Extracted features for sequence 1204 False
# DPC Extracted features for sequence 1205 False
# DPC Extracted features for sequence 1206 False
# DPC Extracted features for sequence 1207 False
# DPC Extracted features for sequence 1208 False
# DPC Extracted features for sequence 1209 False
# DPC Extracted features for sequence 1210 False
# DPC Extracted features for sequence 1211 False
# DPC Extracted features for sequence 1212 False
# DPC Extracted features for sequence 1213 False
# DPC Extracted features for sequence 1214 False
# DPC Extracted features for sequence 1215 False
# DPC Extracted features for sequence 1216 False
# DPC Extracted features for sequence 1217 False
# DPC Extracted features for sequence 1218 False
# DPC Extracted features for sequence 1219 False
# DPC Extracted features for sequence 1220 False
# DPC Extracted features for sequence 1221 False
# DPC Extracted features for sequence 1222 False

# %%
combineNegativeAndPositiveDFs(f'{data_dir}/TS_neg_SPIDER.txt', f'{data_dir}/TS_pos_SPIDER.txt', 'AAC').to_csv(f'processed_dataset/TS_AAC.csv', index=False)
combineNegativeAndPositiveDFs(f'{data_dir}/TS_neg_SPIDER.txt', f'{data_dir}/TS_pos_SPIDER.txt', 'APAAC').to_csv(f'processed_dataset/TS_APAAC.csv', index=False)
combineNegativeAndPositiveDFs(f'{data_dir}/TS_neg_SPIDER.txt', f'{data_dir}/TS_pos_SPIDER.txt', 'CTD').to_csv(f'processed_dataset/TS_CTD.csv', index=False)
combineNegativeAndPositiveDFs(f'{data_dir}/TS_neg_SPIDER.txt', f'{data_dir}/TS_pos_SPIDER.txt', 'PAAC').to_csv(f'processed_dataset/TS_PAAC.csv', index=False)
combineNegativeAndPositiveDFs(f'{data_dir}/TS_neg_SPIDER.txt', f'{data_dir}/TS_pos_SPIDER.txt', 'DPC').to_csv(f'processed_dataset/TS_DPC.csv', index=False)
# Out:
# AAC Extracted features for sequence 0 True
# AAC Extracted features for sequence 1 True
# AAC Extracted features for sequence 2 True
# AAC Extracted features for sequence 3 True
# AAC Extracted features for sequence 4 True
# AAC Extracted features for sequence 5 True
# AAC Extracted features for sequence 6 True
# AAC Extracted features for sequence 7 True
# AAC Extracted features for sequence 8 True
# AAC Extracted features for sequence 9 True
# AAC Extracted features for sequence 10 True
# AAC Extracted features for sequence 11 True
# AAC Extracted features for sequence 12 True
# AAC Extracted features for sequence 13 True
# AAC Extracted features for sequence 14 True
# AAC Extracted features for sequence 15 True
# AAC Extracted features for sequence 16 True
# AAC Extracted features for sequence 17 True
# AAC Extracted features for sequence 18 True
# AAC Extracted features for sequence 19 True
# AAC Extracted features for sequence 20 True
# AAC Extracted features for sequence 21 True
# AAC Extracted features for sequence 22 True
# AAC Extracted features for sequence 23 True
# AAC Extracted features for sequence 24 True
# AAC Extracted features for sequence 25 True
# AAC Extracted features for sequence 26 True
# AAC Extracted features for sequence 27 True
# AAC Extracted features for sequence 28 True
# AAC Extracted features for sequence 29 True
# AAC Extracted features for sequence 30 True
# AAC Extracted features for sequence 31 True
# AAC Extracted features for sequence 32 True
# AAC Extracted features for sequence 33 True
# AAC Extracted features for sequence 34 True
# AAC Extracted features for sequence 35 True
# AAC Extracted features for sequence 36 True
# AAC Extracted features for sequence 37 True
# AAC Extracted features for sequence 38 True
# AAC Extracted features for sequence 39 True
# AAC Extracted features for sequence 40 True
# AAC Extracted features for sequence 41 True
# AAC Extracted features for sequence 42 True
# AAC Extracted features for sequence 43 True
# AAC Extracted features for sequence 44 True
# AAC Extracted features for sequence 45 True
# AAC Extracted features for sequence 46 True
# AAC Extracted features for sequence 47 True
# AAC Extracted features for sequence 48 True
# AAC Extracted features for sequence 49 True
# AAC Extracted features for sequence 50 True
# AAC Extracted features for sequence 51 True
# AAC Extracted features for sequence 52 True
# AAC Extracted features for sequence 53 True
# AAC Extracted features for sequence 54 True
# AAC Extracted features for sequence 55 True
# AAC Extracted features for sequence 56 True
# AAC Extracted features for sequence 57 True
# AAC Extracted features for sequence 58 True
# AAC Extracted features for sequence 59 True
# AAC Extracted features for sequence 60 True
# AAC Extracted features for sequence 61 True
# AAC Extracted features for sequence 62 True
# AAC Extracted features for sequence 63 True
# AAC Extracted features for sequence 64 True
# AAC Extracted features for sequence 65 True
# AAC Extracted features for sequence 66 True
# AAC Extracted features for sequence 67 True
# AAC Extracted features for sequence 68 True
# AAC Extracted features for sequence 69 True
# AAC Extracted features for sequence 70 True
# AAC Extracted features for sequence 71 True
# AAC Extracted features for sequence 72 True
# AAC Extracted features for sequence 73 True
# AAC Extracted features for sequence 74 True
# AAC Extracted features for sequence 75 True
# AAC Extracted features for sequence 76 True
# AAC Extracted features for sequence 77 True
# AAC Extracted features for sequence 78 True
# AAC Extracted features for sequence 79 True
# AAC Extracted features for sequence 80 True
# AAC Extracted features for sequence 81 True
# AAC Extracted features for sequence 82 True
# AAC Extracted features for sequence 83 True
# AAC Extracted features for sequence 84 True
# AAC Extracted features for sequence 85 True
# AAC Extracted features for sequence 86 True
# AAC Extracted features for sequence 87 True
# AAC Extracted features for sequence 88 True
# AAC Extracted features for sequence 89 True
# AAC Extracted features for sequence 90 True
# AAC Extracted features for sequence 91 True
# AAC Extracted features for sequence 92 True
# AAC Extracted features for sequence 93 True
# AAC Extracted features for sequence 94 True
# AAC Extracted features for sequence 95 True
# AAC Extracted features for sequence 96 True
# AAC Extracted features for sequence 97 True
# AAC Extracted features for sequence 98 True
# AAC Extracted features for sequence 99 True
# AAC Extracted features for sequence 100 True
# AAC Extracted features for sequence 101 True
# AAC Extracted features for sequence 102 True
# AAC Extracted features for sequence 103 True
# AAC Extracted features for sequence 104 True
# AAC Extracted features for sequence 105 True
# AAC Extracted features for sequence 106 True
# AAC Extracted features for sequence 107 True
# AAC Extracted features for sequence 108 True
# AAC Extracted features for sequence 109 True
# AAC Extracted features for sequence 110 True
# AAC Extracted features for sequence 111 True
# AAC Extracted features for sequence 112 True
# AAC Extracted features for sequence 113 True
# AAC Extracted features for sequence 114 True
# AAC Extracted features for sequence 115 True
# AAC Extracted features for sequence 116 True
# AAC Extracted features for sequence 117 True
# AAC Extracted features for sequence 118 True
# AAC Extracted features for sequence 119 True
# AAC Extracted features for sequence 120 True
# AAC Extracted features for sequence 121 True
# AAC Extracted features for sequence 122 True
# AAC Extracted features for sequence 123 True
# AAC Extracted features for sequence 124 True
# AAC Extracted features for sequence 125 True
# AAC Extracted features for sequence 126 True
# AAC Extracted features for sequence 127 True
# AAC Extracted features for sequence 128 True
# AAC Extracted features for sequence 129 True
# AAC Extracted features for sequence 130 True
# AAC Extracted features for sequence 131 True
# AAC Extracted features for sequence 132 True
# AAC Extracted features for sequence 133 True
# AAC Extracted features for sequence 134 True
# AAC Extracted features for sequence 135 True
# AAC Extracted features for sequence 136 True
# AAC Extracted features for sequence 137 True
# AAC Extracted features for sequence 138 True
# AAC Extracted features for sequence 139 True
# AAC Extracted features for sequence 140 True
# AAC Extracted features for sequence 141 True
# AAC Extracted features for sequence 142 True
# AAC Extracted features for sequence 143 True
# AAC Extracted features for sequence 144 True
# AAC Extracted features for sequence 145 True
# AAC Extracted features for sequence 146 True
# AAC Extracted features for sequence 147 True
# AAC Extracted features for sequence 148 True
# AAC Extracted features for sequence 149 True
# AAC Extracted features for sequence 150 True
# AAC Extracted features for sequence 151 True
# AAC Extracted features for sequence 152 True
# AAC Extracted features for sequence 153 True
# AAC Extracted features for sequence 154 True
# AAC Extracted features for sequence 155 True
# AAC Extracted features for sequence 156 True
# AAC Extracted features for sequence 157 True
# AAC Extracted features for sequence 158 True
# AAC Extracted features for sequence 159 True
# AAC Extracted features for sequence 160 True
# AAC Extracted features for sequence 161 True
# AAC Extracted features for sequence 162 True
# AAC Extracted features for sequence 163 True
# AAC Extracted features for sequence 164 True
# AAC Extracted features for sequence 165 True
# AAC Extracted features for sequence 166 True
# AAC Extracted features for sequence 167 True
# AAC Extracted features for sequence 168 True
# AAC Extracted features for sequence 169 True
# AAC Extracted features for sequence 170 True
# AAC Extracted features for sequence 171 True
# AAC Extracted features for sequence 172 True
# AAC Extracted features for sequence 173 True
# AAC Extracted features for sequence 174 True
# AAC Extracted features for sequence 175 True
# AAC Extracted features for sequence 176 True
# AAC Extracted features for sequence 177 True
# AAC Extracted features for sequence 178 True
# AAC Extracted features for sequence 179 True
# AAC Extracted features for sequence 180 True
# AAC Extracted features for sequence 181 True
# AAC Extracted features for sequence 182 True
# AAC Extracted features for sequence 183 True
# AAC Extracted features for sequence 184 True
# AAC Extracted features for sequence 185 True
# AAC Extracted features for sequence 186 True
# AAC Extracted features for sequence 187 True
# AAC Extracted features for sequence 188 True
# AAC Extracted features for sequence 189 True
# AAC Extracted features for sequence 190 True
# AAC Extracted features for sequence 191 True
# AAC Extracted features for sequence 192 True
# AAC Extracted features for sequence 193 True
# AAC Extracted features for sequence 194 True
# AAC Extracted features for sequence 195 True
# AAC Extracted features for sequence 196 True
# AAC Extracted features for sequence 197 True
# AAC Extracted features for sequence 198 True
# AAC Extracted features for sequence 199 True
# AAC Extracted features for sequence 200 True
# AAC Extracted features for sequence 201 True
# AAC Extracted features for sequence 202 True
# AAC Extracted features for sequence 203 True
# AAC Extracted features for sequence 204 True
# AAC Extracted features for sequence 205 True
# AAC Extracted features for sequence 206 True
# AAC Extracted features for sequence 207 True
# AAC Extracted features for sequence 208 True
# AAC Extracted features for sequence 209 True
# AAC Extracted features for sequence 210 True
# AAC Extracted features for sequence 211 True
# AAC Extracted features for sequence 212 True
# AAC Extracted features for sequence 213 True
# AAC Extracted features for sequence 214 True
# AAC Extracted features for sequence 215 True
# AAC Extracted features for sequence 216 True
# AAC Extracted features for sequence 217 True
# AAC Extracted features for sequence 218 True
# AAC Extracted features for sequence 219 True
# AAC Extracted features for sequence 220 True
# AAC Extracted features for sequence 221 True
# AAC Extracted features for sequence 222 True
# AAC Extracted features for sequence 223 True
# AAC Extracted features for sequence 224 True
# AAC Extracted features for sequence 225 True
# AAC Extracted features for sequence 226 True
# AAC Extracted features for sequence 227 True
# AAC Extracted features for sequence 228 True
# AAC Extracted features for sequence 229 True
# AAC Extracted features for sequence 230 True
# AAC Extracted features for sequence 231 True
# AAC Extracted features for sequence 232 True
# AAC Extracted features for sequence 233 True
# AAC Extracted features for sequence 234 True
# AAC Extracted features for sequence 235 True
# AAC Extracted features for sequence 236 True
# AAC Extracted features for sequence 0 False
# AAC Extracted features for sequence 1 False
# AAC Extracted features for sequence 2 False
# AAC Extracted features for sequence 3 False
# AAC Extracted features for sequence 4 False
# AAC Extracted features for sequence 5 False
# AAC Extracted features for sequence 6 False
# AAC Extracted features for sequence 7 False
# AAC Extracted features for sequence 8 False
# AAC Extracted features for sequence 9 False
# AAC Extracted features for sequence 10 False
# AAC Extracted features for sequence 11 False
# AAC Extracted features for sequence 12 False
# AAC Extracted features for sequence 13 False
# AAC Extracted features for sequence 14 False
# AAC Extracted features for sequence 15 False
# AAC Extracted features for sequence 16 False
# AAC Extracted features for sequence 17 False
# AAC Extracted features for sequence 18 False
# AAC Extracted features for sequence 19 False
# AAC Extracted features for sequence 20 False
# AAC Extracted features for sequence 21 False
# AAC Extracted features for sequence 22 False
# AAC Extracted features for sequence 23 False
# AAC Extracted features for sequence 24 False
# AAC Extracted features for sequence 25 False
# AAC Extracted features for sequence 26 False
# AAC Extracted features for sequence 27 False
# AAC Extracted features for sequence 28 False
# AAC Extracted features for sequence 29 False
# AAC Extracted features for sequence 30 False
# AAC Extracted features for sequence 31 False
# AAC Extracted features for sequence 32 False
# AAC Extracted features for sequence 33 False
# AAC Extracted features for sequence 34 False
# AAC Extracted features for sequence 35 False
# AAC Extracted features for sequence 36 False
# AAC Extracted features for sequence 37 False
# AAC Extracted features for sequence 38 False
# AAC Extracted features for sequence 39 False
# AAC Extracted features for sequence 40 False
# AAC Extracted features for sequence 41 False
# AAC Extracted features for sequence 42 False
# AAC Extracted features for sequence 43 False
# AAC Extracted features for sequence 44 False
# AAC Extracted features for sequence 45 False
# AAC Extracted features for sequence 46 False
# AAC Extracted features for sequence 47 False
# AAC Extracted features for sequence 48 False
# AAC Extracted features for sequence 49 False
# AAC Extracted features for sequence 50 False
# AAC Extracted features for sequence 51 False
# AAC Extracted features for sequence 52 False
# AAC Extracted features for sequence 53 False
# AAC Extracted features for sequence 54 False
# AAC Extracted features for sequence 55 False
# AAC Extracted features for sequence 56 False
# AAC Extracted features for sequence 57 False
# AAC Extracted features for sequence 58 False
# AAC Extracted features for sequence 59 False
# AAC Extracted features for sequence 60 False
# AAC Extracted features for sequence 61 False
# AAC Extracted features for sequence 62 False
# AAC Extracted features for sequence 63 False
# AAC Extracted features for sequence 64 False
# AAC Extracted features for sequence 65 False
# AAC Extracted features for sequence 66 False
# AAC Extracted features for sequence 67 False
# AAC Extracted features for sequence 68 False
# AAC Extracted features for sequence 69 False
# AAC Extracted features for sequence 70 False
# AAC Extracted features for sequence 71 False
# AAC Extracted features for sequence 72 False
# AAC Extracted features for sequence 73 False
# AAC Extracted features for sequence 74 False
# AAC Extracted features for sequence 75 False
# AAC Extracted features for sequence 76 False
# AAC Extracted features for sequence 77 False
# AAC Extracted features for sequence 78 False
# AAC Extracted features for sequence 79 False
# AAC Extracted features for sequence 80 False
# AAC Extracted features for sequence 81 False
# AAC Extracted features for sequence 82 False
# AAC Extracted features for sequence 83 False
# AAC Extracted features for sequence 84 False
# AAC Extracted features for sequence 85 False
# AAC Extracted features for sequence 86 False
# AAC Extracted features for sequence 87 False
# AAC Extracted features for sequence 88 False
# AAC Extracted features for sequence 89 False
# AAC Extracted features for sequence 90 False
# AAC Extracted features for sequence 91 False
# AAC Extracted features for sequence 92 False
# AAC Extracted features for sequence 93 False
# AAC Extracted features for sequence 94 False
# AAC Extracted features for sequence 95 False
# AAC Extracted features for sequence 96 False
# AAC Extracted features for sequence 97 False
# AAC Extracted features for sequence 98 False
# AAC Extracted features for sequence 99 False
# AAC Extracted features for sequence 100 False
# AAC Extracted features for sequence 101 False
# AAC Extracted features for sequence 102 False
# AAC Extracted features for sequence 103 False
# AAC Extracted features for sequence 104 False
# AAC Extracted features for sequence 105 False
# AAC Extracted features for sequence 106 False
# AAC Extracted features for sequence 107 False
# AAC Extracted features for sequence 108 False
# AAC Extracted features for sequence 109 False
# AAC Extracted features for sequence 110 False
# AAC Extracted features for sequence 111 False
# AAC Extracted features for sequence 112 False
# AAC Extracted features for sequence 113 False
# AAC Extracted features for sequence 114 False
# AAC Extracted features for sequence 115 False
# AAC Extracted features for sequence 116 False
# AAC Extracted features for sequence 117 False
# AAC Extracted features for sequence 118 False
# AAC Extracted features for sequence 119 False
# AAC Extracted features for sequence 120 False
# AAC Extracted features for sequence 121 False
# AAC Extracted features for sequence 122 False
# AAC Extracted features for sequence 123 False
# AAC Extracted features for sequence 124 False
# AAC Extracted features for sequence 125 False
# AAC Extracted features for sequence 126 False
# AAC Extracted features for sequence 127 False
# AAC Extracted features for sequence 128 False
# AAC Extracted features for sequence 129 False
# AAC Extracted features for sequence 130 False
# AAC Extracted features for sequence 131 False
# AAC Extracted features for sequence 132 False
# AAC Extracted features for sequence 133 False
# AAC Extracted features for sequence 134 False
# AAC Extracted features for sequence 135 False
# AAC Extracted features for sequence 136 False
# AAC Extracted features for sequence 137 False
# AAC Extracted features for sequence 138 False
# AAC Extracted features for sequence 139 False
# AAC Extracted features for sequence 140 False
# AAC Extracted features for sequence 141 False
# AAC Extracted features for sequence 142 False
# AAC Extracted features for sequence 143 False
# AAC Extracted features for sequence 144 False
# AAC Extracted features for sequence 145 False
# AAC Extracted features for sequence 146 False
# AAC Extracted features for sequence 147 False
# AAC Extracted features for sequence 148 False
# AAC Extracted features for sequence 149 False
# AAC Extracted features for sequence 150 False
# AAC Extracted features for sequence 151 False
# AAC Extracted features for sequence 152 False
# AAC Extracted features for sequence 153 False
# AAC Extracted features for sequence 154 False
# AAC Extracted features for sequence 155 False
# AAC Extracted features for sequence 156 False
# AAC Extracted features for sequence 157 False
# AAC Extracted features for sequence 158 False
# AAC Extracted features for sequence 159 False
# AAC Extracted features for sequence 160 False
# AAC Extracted features for sequence 161 False
# AAC Extracted features for sequence 162 False
# AAC Extracted features for sequence 163 False
# AAC Extracted features for sequence 164 False
# AAC Extracted features for sequence 165 False
# AAC Extracted features for sequence 166 False
# AAC Extracted features for sequence 167 False
# AAC Extracted features for sequence 168 False
# AAC Extracted features for sequence 169 False
# AAC Extracted features for sequence 170 False
# AAC Extracted features for sequence 171 False
# AAC Extracted features for sequence 172 False
# AAC Extracted features for sequence 173 False
# AAC Extracted features for sequence 174 False
# AAC Extracted features for sequence 175 False
# AAC Extracted features for sequence 176 False
# AAC Extracted features for sequence 177 False
# AAC Extracted features for sequence 178 False
# AAC Extracted features for sequence 179 False
# AAC Extracted features for sequence 180 False
# AAC Extracted features for sequence 181 False
# AAC Extracted features for sequence 182 False
# AAC Extracted features for sequence 183 False
# AAC Extracted features for sequence 184 False
# AAC Extracted features for sequence 185 False
# AAC Extracted features for sequence 186 False
# AAC Extracted features for sequence 187 False
# AAC Extracted features for sequence 188 False
# AAC Extracted features for sequence 189 False
# AAC Extracted features for sequence 190 False
# AAC Extracted features for sequence 191 False
# AAC Extracted features for sequence 192 False
# AAC Extracted features for sequence 193 False
# AAC Extracted features for sequence 194 False
# AAC Extracted features for sequence 195 False
# AAC Extracted features for sequence 196 False
# AAC Extracted features for sequence 197 False
# AAC Extracted features for sequence 198 False
# AAC Extracted features for sequence 199 False
# AAC Extracted features for sequence 200 False
# AAC Extracted features for sequence 201 False
# AAC Extracted features for sequence 202 False
# AAC Extracted features for sequence 203 False
# AAC Extracted features for sequence 204 False
# AAC Extracted features for sequence 205 False
# AAC Extracted features for sequence 206 False
# AAC Extracted features for sequence 207 False
# AAC Extracted features for sequence 208 False
# AAC Extracted features for sequence 209 False
# AAC Extracted features for sequence 210 False
# AAC Extracted features for sequence 211 False
# AAC Extracted features for sequence 212 False
# AAC Extracted features for sequence 213 False
# AAC Extracted features for sequence 214 False
# AAC Extracted features for sequence 215 False
# AAC Extracted features for sequence 216 False
# AAC Extracted features for sequence 217 False
# AAC Extracted features for sequence 218 False
# AAC Extracted features for sequence 219 False
# AAC Extracted features for sequence 220 False
# AAC Extracted features for sequence 221 False
# AAC Extracted features for sequence 222 False
# AAC Extracted features for sequence 223 False
# APAAC Extracted features for sequence 0 True
# APAAC Extracted features for sequence 1 True
# APAAC Extracted features for sequence 2 True
# APAAC Extracted features for sequence 3 True
# APAAC Extracted features for sequence 4 True
# APAAC Extracted features for sequence 5 True
# APAAC Extracted features for sequence 6 True
# APAAC Extracted features for sequence 7 True
# APAAC Extracted features for sequence 8 True
# APAAC Extracted features for sequence 9 True
# APAAC Extracted features for sequence 10 True
# APAAC Extracted features for sequence 11 True
# APAAC Extracted features for sequence 12 True
# APAAC Extracted features for sequence 13 True
# APAAC Extracted features for sequence 14 True
# APAAC Extracted features for sequence 15 True
# APAAC Extracted features for sequence 16 True
# APAAC Extracted features for sequence 17 True
# APAAC Extracted features for sequence 18 True
# APAAC Extracted features for sequence 19 True
# APAAC Extracted features for sequence 20 True
# APAAC Extracted features for sequence 21 True
# APAAC Extracted features for sequence 22 True
# APAAC Extracted features for sequence 23 True
# APAAC Extracted features for sequence 24 True
# APAAC Extracted features for sequence 25 True
# APAAC Extracted features for sequence 26 True
# APAAC Extracted features for sequence 27 True
# APAAC Extracted features for sequence 28 True
# APAAC Extracted features for sequence 29 True
# APAAC Extracted features for sequence 30 True
# APAAC Extracted features for sequence 31 True
# APAAC Extracted features for sequence 32 True
# APAAC Extracted features for sequence 33 True
# APAAC Extracted features for sequence 34 True
# APAAC Extracted features for sequence 35 True
# APAAC Extracted features for sequence 36 True
# APAAC Extracted features for sequence 37 True
# APAAC Extracted features for sequence 38 True
# APAAC Extracted features for sequence 39 True
# APAAC Extracted features for sequence 40 True
# APAAC Extracted features for sequence 41 True
# APAAC Extracted features for sequence 42 True
# APAAC Extracted features for sequence 43 True
# APAAC Extracted features for sequence 44 True
# APAAC Extracted features for sequence 45 True
# APAAC Extracted features for sequence 46 True
# APAAC Extracted features for sequence 47 True
# APAAC Extracted features for sequence 48 True
# APAAC Extracted features for sequence 49 True
# APAAC Extracted features for sequence 50 True
# APAAC Extracted features for sequence 51 True
# APAAC Extracted features for sequence 52 True
# APAAC Extracted features for sequence 53 True
# APAAC Extracted features for sequence 54 True
# APAAC Extracted features for sequence 55 True
# APAAC Extracted features for sequence 56 True
# APAAC Extracted features for sequence 57 True
# APAAC Extracted features for sequence 58 True
# APAAC Extracted features for sequence 59 True
# APAAC Extracted features for sequence 60 True
# APAAC Extracted features for sequence 61 True
# APAAC Extracted features for sequence 62 True
# APAAC Extracted features for sequence 63 True
# APAAC Extracted features for sequence 64 True
# APAAC Extracted features for sequence 65 True
# APAAC Extracted features for sequence 66 True
# APAAC Extracted features for sequence 67 True
# APAAC Extracted features for sequence 68 True
# APAAC Extracted features for sequence 69 True
# APAAC Extracted features for sequence 70 True
# APAAC Extracted features for sequence 71 True
# APAAC Extracted features for sequence 72 True
# APAAC Extracted features for sequence 73 True
# APAAC Extracted features for sequence 74 True
# APAAC Extracted features for sequence 75 True
# APAAC Extracted features for sequence 76 True
# APAAC Extracted features for sequence 77 True
# APAAC Extracted features for sequence 78 True
# APAAC Extracted features for sequence 79 True
# APAAC Extracted features for sequence 80 True
# APAAC Extracted features for sequence 81 True
# APAAC Extracted features for sequence 82 True
# APAAC Extracted features for sequence 83 True
# APAAC Extracted features for sequence 84 True
# APAAC Extracted features for sequence 85 True
# APAAC Extracted features for sequence 86 True
# APAAC Extracted features for sequence 87 True
# APAAC Extracted features for sequence 88 True
# APAAC Extracted features for sequence 89 True
# APAAC Extracted features for sequence 90 True
# APAAC Extracted features for sequence 91 True
# APAAC Extracted features for sequence 92 True
# APAAC Extracted features for sequence 93 True
# APAAC Extracted features for sequence 94 True
# APAAC Extracted features for sequence 95 True
# APAAC Extracted features for sequence 96 True
# APAAC Extracted features for sequence 97 True
# APAAC Extracted features for sequence 98 True
# APAAC Extracted features for sequence 99 True
# APAAC Extracted features for sequence 100 True
# APAAC Extracted features for sequence 101 True
# APAAC Extracted features for sequence 102 True
# APAAC Extracted features for sequence 103 True
# APAAC Extracted features for sequence 104 True
# APAAC Extracted features for sequence 105 True
# APAAC Extracted features for sequence 106 True
# APAAC Extracted features for sequence 107 True
# APAAC Extracted features for sequence 108 True
# APAAC Extracted features for sequence 109 True
# APAAC Extracted features for sequence 110 True
# APAAC Extracted features for sequence 111 True
# APAAC Extracted features for sequence 112 True
# APAAC Extracted features for sequence 113 True
# APAAC Extracted features for sequence 114 True
# APAAC Extracted features for sequence 115 True
# APAAC Extracted features for sequence 116 True
# APAAC Extracted features for sequence 117 True
# APAAC Extracted features for sequence 118 True
# APAAC Extracted features for sequence 119 True
# APAAC Extracted features for sequence 120 True
# APAAC Extracted features for sequence 121 True
# APAAC Extracted features for sequence 122 True
# APAAC Extracted features for sequence 123 True
# APAAC Extracted features for sequence 124 True
# APAAC Extracted features for sequence 125 True
# APAAC Extracted features for sequence 126 True
# APAAC Extracted features for sequence 127 True
# APAAC Extracted features for sequence 128 True
# APAAC Extracted features for sequence 129 True
# APAAC Extracted features for sequence 130 True
# APAAC Extracted features for sequence 131 True
# APAAC Extracted features for sequence 132 True
# APAAC Extracted features for sequence 133 True
# APAAC Extracted features for sequence 134 True
# APAAC Extracted features for sequence 135 True
# APAAC Extracted features for sequence 136 True
# APAAC Extracted features for sequence 137 True
# APAAC Extracted features for sequence 138 True
# APAAC Extracted features for sequence 139 True
# APAAC Extracted features for sequence 140 True
# APAAC Extracted features for sequence 141 True
# APAAC Extracted features for sequence 142 True
# APAAC Extracted features for sequence 143 True
# APAAC Extracted features for sequence 144 True
# APAAC Extracted features for sequence 145 True
# APAAC Extracted features for sequence 146 True
# APAAC Extracted features for sequence 147 True
# APAAC Extracted features for sequence 148 True
# APAAC Extracted features for sequence 149 True
# APAAC Extracted features for sequence 150 True
# APAAC Extracted features for sequence 151 True
# APAAC Extracted features for sequence 152 True
# APAAC Extracted features for sequence 153 True
# APAAC Extracted features for sequence 154 True
# APAAC Extracted features for sequence 155 True
# APAAC Extracted features for sequence 156 True
# APAAC Extracted features for sequence 157 True
# APAAC Extracted features for sequence 158 True
# APAAC Extracted features for sequence 159 True
# APAAC Extracted features for sequence 160 True
# APAAC Extracted features for sequence 161 True
# APAAC Extracted features for sequence 162 True
# APAAC Extracted features for sequence 163 True
# APAAC Extracted features for sequence 164 True
# APAAC Extracted features for sequence 165 True
# APAAC Extracted features for sequence 166 True
# APAAC Extracted features for sequence 167 True
# APAAC Extracted features for sequence 168 True
# APAAC Extracted features for sequence 169 True
# APAAC Extracted features for sequence 170 True
# APAAC Extracted features for sequence 171 True
# APAAC Extracted features for sequence 172 True
# APAAC Extracted features for sequence 173 True
# APAAC Extracted features for sequence 174 True
# APAAC Extracted features for sequence 175 True
# APAAC Extracted features for sequence 176 True
# APAAC Extracted features for sequence 177 True
# APAAC Extracted features for sequence 178 True
# APAAC Extracted features for sequence 179 True
# APAAC Extracted features for sequence 180 True
# APAAC Extracted features for sequence 181 True
# APAAC Extracted features for sequence 182 True
# APAAC Extracted features for sequence 183 True
# APAAC Extracted features for sequence 184 True
# APAAC Extracted features for sequence 185 True
# APAAC Extracted features for sequence 186 True
# APAAC Extracted features for sequence 187 True
# APAAC Extracted features for sequence 188 True
# APAAC Extracted features for sequence 189 True
# APAAC Extracted features for sequence 190 True
# APAAC Extracted features for sequence 191 True
# APAAC Extracted features for sequence 192 True
# APAAC Extracted features for sequence 193 True
# APAAC Extracted features for sequence 194 True
# APAAC Extracted features for sequence 195 True
# APAAC Extracted features for sequence 196 True
# APAAC Extracted features for sequence 197 True
# APAAC Extracted features for sequence 198 True
# APAAC Extracted features for sequence 199 True
# APAAC Extracted features for sequence 200 True
# APAAC Extracted features for sequence 201 True
# APAAC Extracted features for sequence 202 True
# APAAC Extracted features for sequence 203 True
# APAAC Extracted features for sequence 204 True
# APAAC Extracted features for sequence 205 True
# APAAC Extracted features for sequence 206 True
# APAAC Extracted features for sequence 207 True
# APAAC Extracted features for sequence 208 True
# APAAC Extracted features for sequence 209 True
# APAAC Extracted features for sequence 210 True
# APAAC Extracted features for sequence 211 True
# APAAC Extracted features for sequence 212 True
# APAAC Extracted features for sequence 213 True
# APAAC Extracted features for sequence 214 True
# APAAC Extracted features for sequence 215 True
# APAAC Extracted features for sequence 216 True
# APAAC Extracted features for sequence 217 True
# APAAC Extracted features for sequence 218 True
# APAAC Extracted features for sequence 219 True
# APAAC Extracted features for sequence 220 True
# APAAC Extracted features for sequence 221 True
# APAAC Extracted features for sequence 222 True
# APAAC Extracted features for sequence 223 True
# APAAC Extracted features for sequence 224 True
# APAAC Extracted features for sequence 225 True
# APAAC Extracted features for sequence 226 True
# APAAC Extracted features for sequence 227 True
# APAAC Extracted features for sequence 228 True
# APAAC Extracted features for sequence 229 True
# APAAC Extracted features for sequence 230 True
# APAAC Extracted features for sequence 231 True
# APAAC Extracted features for sequence 232 True
# APAAC Extracted features for sequence 233 True
# APAAC Extracted features for sequence 234 True
# APAAC Extracted features for sequence 235 True
# APAAC Extracted features for sequence 236 True
# APAAC Extracted features for sequence 0 False
# APAAC Extracted features for sequence 1 False
# APAAC Extracted features for sequence 2 False
# APAAC Extracted features for sequence 3 False
# APAAC Extracted features for sequence 4 False
# APAAC Extracted features for sequence 5 False
# APAAC Extracted features for sequence 6 False
# APAAC Extracted features for sequence 7 False
# APAAC Extracted features for sequence 8 False
# APAAC Extracted features for sequence 9 False
# APAAC Extracted features for sequence 10 False
# APAAC Extracted features for sequence 11 False
# APAAC Extracted features for sequence 12 False
# APAAC Extracted features for sequence 13 False
# APAAC Extracted features for sequence 14 False
# APAAC Extracted features for sequence 15 False
# APAAC Extracted features for sequence 16 False
# APAAC Extracted features for sequence 17 False
# APAAC Extracted features for sequence 18 False
# APAAC Extracted features for sequence 19 False
# APAAC Extracted features for sequence 20 False
# APAAC Extracted features for sequence 21 False
# APAAC Extracted features for sequence 22 False
# APAAC Extracted features for sequence 23 False
# APAAC Extracted features for sequence 24 False
# APAAC Extracted features for sequence 25 False
# APAAC Extracted features for sequence 26 False
# APAAC Extracted features for sequence 27 False
# APAAC Extracted features for sequence 28 False
# APAAC Extracted features for sequence 29 False
# APAAC Extracted features for sequence 30 False
# APAAC Extracted features for sequence 31 False
# APAAC Extracted features for sequence 32 False
# APAAC Extracted features for sequence 33 False
# APAAC Extracted features for sequence 34 False
# APAAC Extracted features for sequence 35 False
# APAAC Extracted features for sequence 36 False
# APAAC Extracted features for sequence 37 False
# APAAC Extracted features for sequence 38 False
# APAAC Extracted features for sequence 39 False
# APAAC Extracted features for sequence 40 False
# APAAC Extracted features for sequence 41 False
# APAAC Extracted features for sequence 42 False
# APAAC Extracted features for sequence 43 False
# APAAC Extracted features for sequence 44 False
# APAAC Extracted features for sequence 45 False
# APAAC Extracted features for sequence 46 False
# APAAC Extracted features for sequence 47 False
# APAAC Extracted features for sequence 48 False
# APAAC Extracted features for sequence 49 False
# APAAC Extracted features for sequence 50 False
# APAAC Extracted features for sequence 51 False
# APAAC Extracted features for sequence 52 False
# APAAC Extracted features for sequence 53 False
# APAAC Extracted features for sequence 54 False
# APAAC Extracted features for sequence 55 False
# APAAC Extracted features for sequence 56 False
# APAAC Extracted features for sequence 57 False
# APAAC Extracted features for sequence 58 False
# APAAC Extracted features for sequence 59 False
# APAAC Extracted features for sequence 60 False
# APAAC Extracted features for sequence 61 False
# APAAC Extracted features for sequence 62 False
# APAAC Extracted features for sequence 63 False
# APAAC Extracted features for sequence 64 False
# APAAC Extracted features for sequence 65 False
# APAAC Extracted features for sequence 66 False
# APAAC Extracted features for sequence 67 False
# APAAC Extracted features for sequence 68 False
# APAAC Extracted features for sequence 69 False
# APAAC Extracted features for sequence 70 False
# APAAC Extracted features for sequence 71 False
# APAAC Extracted features for sequence 72 False
# APAAC Extracted features for sequence 73 False
# APAAC Extracted features for sequence 74 False
# APAAC Extracted features for sequence 75 False
# APAAC Extracted features for sequence 76 False
# APAAC Extracted features for sequence 77 False
# APAAC Extracted features for sequence 78 False
# APAAC Extracted features for sequence 79 False
# APAAC Extracted features for sequence 80 False
# APAAC Extracted features for sequence 81 False
# APAAC Extracted features for sequence 82 False
# APAAC Extracted features for sequence 83 False
# APAAC Extracted features for sequence 84 False
# APAAC Extracted features for sequence 85 False
# APAAC Extracted features for sequence 86 False
# APAAC Extracted features for sequence 87 False
# APAAC Extracted features for sequence 88 False
# APAAC Extracted features for sequence 89 False
# APAAC Extracted features for sequence 90 False
# APAAC Extracted features for sequence 91 False
# APAAC Extracted features for sequence 92 False
# APAAC Extracted features for sequence 93 False
# APAAC Extracted features for sequence 94 False
# APAAC Extracted features for sequence 95 False
# APAAC Extracted features for sequence 96 False
# APAAC Extracted features for sequence 97 False
# APAAC Extracted features for sequence 98 False
# APAAC Extracted features for sequence 99 False
# APAAC Extracted features for sequence 100 False
# APAAC Extracted features for sequence 101 False
# APAAC Extracted features for sequence 102 False
# APAAC Extracted features for sequence 103 False
# APAAC Extracted features for sequence 104 False
# APAAC Extracted features for sequence 105 False
# APAAC Extracted features for sequence 106 False
# APAAC Extracted features for sequence 107 False
# APAAC Extracted features for sequence 108 False
# APAAC Extracted features for sequence 109 False
# APAAC Extracted features for sequence 110 False
# APAAC Extracted features for sequence 111 False
# APAAC Extracted features for sequence 112 False
# APAAC Extracted features for sequence 113 False
# APAAC Extracted features for sequence 114 False
# APAAC Extracted features for sequence 115 False
# APAAC Extracted features for sequence 116 False
# APAAC Extracted features for sequence 117 False
# APAAC Extracted features for sequence 118 False
# APAAC Extracted features for sequence 119 False
# APAAC Extracted features for sequence 120 False
# APAAC Extracted features for sequence 121 False
# APAAC Extracted features for sequence 122 False
# APAAC Extracted features for sequence 123 False
# APAAC Extracted features for sequence 124 False
# APAAC Extracted features for sequence 125 False
# APAAC Extracted features for sequence 126 False
# APAAC Extracted features for sequence 127 False
# APAAC Extracted features for sequence 128 False
# APAAC Extracted features for sequence 129 False
# APAAC Extracted features for sequence 130 False
# APAAC Extracted features for sequence 131 False
# APAAC Extracted features for sequence 132 False
# APAAC Extracted features for sequence 133 False
# APAAC Extracted features for sequence 134 False
# APAAC Extracted features for sequence 135 False
# APAAC Extracted features for sequence 136 False
# APAAC Extracted features for sequence 137 False
# APAAC Extracted features for sequence 138 False
# APAAC Extracted features for sequence 139 False
# APAAC Extracted features for sequence 140 False
# APAAC Extracted features for sequence 141 False
# APAAC Extracted features for sequence 142 False
# APAAC Extracted features for sequence 143 False
# APAAC Extracted features for sequence 144 False
# APAAC Extracted features for sequence 145 False
# APAAC Extracted features for sequence 146 False
# APAAC Extracted features for sequence 147 False
# APAAC Extracted features for sequence 148 False
# APAAC Extracted features for sequence 149 False
# APAAC Extracted features for sequence 150 False
# APAAC Extracted features for sequence 151 False
# APAAC Extracted features for sequence 152 False
# APAAC Extracted features for sequence 153 False
# APAAC Extracted features for sequence 154 False
# APAAC Extracted features for sequence 155 False
# APAAC Extracted features for sequence 156 False
# APAAC Extracted features for sequence 157 False
# APAAC Extracted features for sequence 158 False
# APAAC Extracted features for sequence 159 False
# APAAC Extracted features for sequence 160 False
# APAAC Extracted features for sequence 161 False
# APAAC Extracted features for sequence 162 False
# APAAC Extracted features for sequence 163 False
# APAAC Extracted features for sequence 164 False
# APAAC Extracted features for sequence 165 False
# APAAC Extracted features for sequence 166 False
# APAAC Extracted features for sequence 167 False
# APAAC Extracted features for sequence 168 False
# APAAC Extracted features for sequence 169 False
# APAAC Extracted features for sequence 170 False
# APAAC Extracted features for sequence 171 False
# APAAC Extracted features for sequence 172 False
# APAAC Extracted features for sequence 173 False
# APAAC Extracted features for sequence 174 False
# APAAC Extracted features for sequence 175 False
# APAAC Extracted features for sequence 176 False
# APAAC Extracted features for sequence 177 False
# APAAC Extracted features for sequence 178 False
# APAAC Extracted features for sequence 179 False
# APAAC Extracted features for sequence 180 False
# APAAC Extracted features for sequence 181 False
# APAAC Extracted features for sequence 182 False
# APAAC Extracted features for sequence 183 False
# APAAC Extracted features for sequence 184 False
# APAAC Extracted features for sequence 185 False
# APAAC Extracted features for sequence 186 False
# APAAC Extracted features for sequence 187 False
# APAAC Extracted features for sequence 188 False
# APAAC Extracted features for sequence 189 False
# APAAC Extracted features for sequence 190 False
# APAAC Extracted features for sequence 191 False
# APAAC Extracted features for sequence 192 False
# APAAC Extracted features for sequence 193 False
# APAAC Extracted features for sequence 194 False
# APAAC Extracted features for sequence 195 False
# APAAC Extracted features for sequence 196 False
# APAAC Extracted features for sequence 197 False
# APAAC Extracted features for sequence 198 False
# APAAC Extracted features for sequence 199 False
# APAAC Extracted features for sequence 200 False
# APAAC Extracted features for sequence 201 False
# APAAC Extracted features for sequence 202 False
# APAAC Extracted features for sequence 203 False
# APAAC Extracted features for sequence 204 False
# APAAC Extracted features for sequence 205 False
# APAAC Extracted features for sequence 206 False
# APAAC Extracted features for sequence 207 False
# APAAC Extracted features for sequence 208 False
# APAAC Extracted features for sequence 209 False
# APAAC Extracted features for sequence 210 False
# APAAC Extracted features for sequence 211 False
# APAAC Extracted features for sequence 212 False
# APAAC Extracted features for sequence 213 False
# APAAC Extracted features for sequence 214 False
# APAAC Extracted features for sequence 215 False
# APAAC Extracted features for sequence 216 False
# APAAC Extracted features for sequence 217 False
# APAAC Extracted features for sequence 218 False
# APAAC Extracted features for sequence 219 False
# APAAC Extracted features for sequence 220 False
# APAAC Extracted features for sequence 221 False
# APAAC Extracted features for sequence 222 False
# APAAC Extracted features for sequence 223 False
# CTD Extracted features for sequence 0 True
# CTD Extracted features for sequence 1 True
# CTD Extracted features for sequence 2 True
# CTD Extracted features for sequence 3 True
# CTD Extracted features for sequence 4 True
# CTD Extracted features for sequence 5 True
# CTD Extracted features for sequence 6 True
# CTD Extracted features for sequence 7 True
# CTD Extracted features for sequence 8 True
# CTD Extracted features for sequence 9 True
# CTD Extracted features for sequence 10 True
# CTD Extracted features for sequence 11 True
# CTD Extracted features for sequence 12 True
# CTD Extracted features for sequence 13 True
# CTD Extracted features for sequence 14 True
# CTD Extracted features for sequence 15 True
# CTD Extracted features for sequence 16 True
# CTD Extracted features for sequence 17 True
# CTD Extracted features for sequence 18 True
# CTD Extracted features for sequence 19 True
# CTD Extracted features for sequence 20 True
# CTD Extracted features for sequence 21 True
# CTD Extracted features for sequence 22 True
# CTD Extracted features for sequence 23 True
# CTD Extracted features for sequence 24 True
# CTD Extracted features for sequence 25 True
# CTD Extracted features for sequence 26 True
# CTD Extracted features for sequence 27 True
# CTD Extracted features for sequence 28 True
# CTD Extracted features for sequence 29 True
# CTD Extracted features for sequence 30 True
# CTD Extracted features for sequence 31 True
# CTD Extracted features for sequence 32 True
# CTD Extracted features for sequence 33 True
# CTD Extracted features for sequence 34 True
# CTD Extracted features for sequence 35 True
# CTD Extracted features for sequence 36 True
# CTD Extracted features for sequence 37 True
# CTD Extracted features for sequence 38 True
# CTD Extracted features for sequence 39 True
# CTD Extracted features for sequence 40 True
# CTD Extracted features for sequence 41 True
# CTD Extracted features for sequence 42 True
# CTD Extracted features for sequence 43 True
# CTD Extracted features for sequence 44 True
# CTD Extracted features for sequence 45 True
# CTD Extracted features for sequence 46 True
# CTD Extracted features for sequence 47 True
# CTD Extracted features for sequence 48 True
# CTD Extracted features for sequence 49 True
# CTD Extracted features for sequence 50 True
# CTD Extracted features for sequence 51 True
# CTD Extracted features for sequence 52 True
# CTD Extracted features for sequence 53 True
# CTD Extracted features for sequence 54 True
# CTD Extracted features for sequence 55 True
# CTD Extracted features for sequence 56 True
# CTD Extracted features for sequence 57 True
# CTD Extracted features for sequence 58 True
# CTD Extracted features for sequence 59 True
# CTD Extracted features for sequence 60 True
# CTD Extracted features for sequence 61 True
# CTD Extracted features for sequence 62 True
# CTD Extracted features for sequence 63 True
# CTD Extracted features for sequence 64 True
# CTD Extracted features for sequence 65 True
# CTD Extracted features for sequence 66 True
# CTD Extracted features for sequence 67 True
# CTD Extracted features for sequence 68 True
# CTD Extracted features for sequence 69 True
# CTD Extracted features for sequence 70 True
# CTD Extracted features for sequence 71 True
# CTD Extracted features for sequence 72 True
# CTD Extracted features for sequence 73 True
# CTD Extracted features for sequence 74 True
# CTD Extracted features for sequence 75 True
# CTD Extracted features for sequence 76 True
# CTD Extracted features for sequence 77 True
# CTD Extracted features for sequence 78 True
# CTD Extracted features for sequence 79 True
# CTD Extracted features for sequence 80 True
# CTD Extracted features for sequence 81 True
# CTD Extracted features for sequence 82 True
# CTD Extracted features for sequence 83 True
# CTD Extracted features for sequence 84 True
# CTD Extracted features for sequence 85 True
# CTD Extracted features for sequence 86 True
# CTD Extracted features for sequence 87 True
# CTD Extracted features for sequence 88 True
# CTD Extracted features for sequence 89 True
# CTD Extracted features for sequence 90 True
# CTD Extracted features for sequence 91 True
# CTD Extracted features for sequence 92 True
# CTD Extracted features for sequence 93 True
# CTD Extracted features for sequence 94 True
# CTD Extracted features for sequence 95 True
# CTD Extracted features for sequence 96 True
# CTD Extracted features for sequence 97 True
# CTD Extracted features for sequence 98 True
# CTD Extracted features for sequence 99 True
# CTD Extracted features for sequence 100 True
# CTD Extracted features for sequence 101 True
# CTD Extracted features for sequence 102 True
# CTD Extracted features for sequence 103 True
# CTD Extracted features for sequence 104 True
# CTD Extracted features for sequence 105 True
# CTD Extracted features for sequence 106 True
# CTD Extracted features for sequence 107 True
# CTD Extracted features for sequence 108 True
# CTD Extracted features for sequence 109 True
# CTD Extracted features for sequence 110 True
# CTD Extracted features for sequence 111 True
# CTD Extracted features for sequence 112 True
# CTD Extracted features for sequence 113 True
# CTD Extracted features for sequence 114 True
# CTD Extracted features for sequence 115 True
# CTD Extracted features for sequence 116 True
# CTD Extracted features for sequence 117 True
# CTD Extracted features for sequence 118 True
# CTD Extracted features for sequence 119 True
# CTD Extracted features for sequence 120 True
# CTD Extracted features for sequence 121 True
# CTD Extracted features for sequence 122 True
# CTD Extracted features for sequence 123 True
# CTD Extracted features for sequence 124 True
# CTD Extracted features for sequence 125 True
# ...
# DPC Extracted features for sequence 108 True
# DPC Extracted features for sequence 109 True
# DPC Extracted features for sequence 110 True
# DPC Extracted features for sequence 111 True
# DPC Extracted features for sequence 112 True
# DPC Extracted features for sequence 113 True
# DPC Extracted features for sequence 114 True
# DPC Extracted features for sequence 115 True
# DPC Extracted features for sequence 116 True
# DPC Extracted features for sequence 117 True
# DPC Extracted features for sequence 118 True
# DPC Extracted features for sequence 119 True
# DPC Extracted features for sequence 120 True
# DPC Extracted features for sequence 121 True
# DPC Extracted features for sequence 122 True
# DPC Extracted features for sequence 123 True
# DPC Extracted features for sequence 124 True
# DPC Extracted features for sequence 125 True
# DPC Extracted features for sequence 126 True
# DPC Extracted features for sequence 127 True
# DPC Extracted features for sequence 128 True
# DPC Extracted features for sequence 129 True
# DPC Extracted features for sequence 130 True
# DPC Extracted features for sequence 131 True
# DPC Extracted features for sequence 132 True
# DPC Extracted features for sequence 133 True
# DPC Extracted features for sequence 134 True
# DPC Extracted features for sequence 135 True
# DPC Extracted features for sequence 136 True
# DPC Extracted features for sequence 137 True
# DPC Extracted features for sequence 138 True
# DPC Extracted features for sequence 139 True
# DPC Extracted features for sequence 140 True
# DPC Extracted features for sequence 141 True
# DPC Extracted features for sequence 142 True
# DPC Extracted features for sequence 143 True
# DPC Extracted features for sequence 144 True
# DPC Extracted features for sequence 145 True
# DPC Extracted features for sequence 146 True
# DPC Extracted features for sequence 147 True
# DPC Extracted features for sequence 148 True
# DPC Extracted features for sequence 149 True
# DPC Extracted features for sequence 150 True
# DPC Extracted features for sequence 151 True
# DPC Extracted features for sequence 152 True
# DPC Extracted features for sequence 153 True
# DPC Extracted features for sequence 154 True
# DPC Extracted features for sequence 155 True
# DPC Extracted features for sequence 156 True
# DPC Extracted features for sequence 157 True
# DPC Extracted features for sequence 158 True
# DPC Extracted features for sequence 159 True
# DPC Extracted features for sequence 160 True
# DPC Extracted features for sequence 161 True
# DPC Extracted features for sequence 162 True
# DPC Extracted features for sequence 163 True
# DPC Extracted features for sequence 164 True
# DPC Extracted features for sequence 165 True
# DPC Extracted features for sequence 166 True
# DPC Extracted features for sequence 167 True
# DPC Extracted features for sequence 168 True
# DPC Extracted features for sequence 169 True
# DPC Extracted features for sequence 170 True
# DPC Extracted features for sequence 171 True
# DPC Extracted features for sequence 172 True
# DPC Extracted features for sequence 173 True
# DPC Extracted features for sequence 174 True
# DPC Extracted features for sequence 175 True
# DPC Extracted features for sequence 176 True
# DPC Extracted features for sequence 177 True
# DPC Extracted features for sequence 178 True
# DPC Extracted features for sequence 179 True
# DPC Extracted features for sequence 180 True
# DPC Extracted features for sequence 181 True
# DPC Extracted features for sequence 182 True
# DPC Extracted features for sequence 183 True
# DPC Extracted features for sequence 184 True
# DPC Extracted features for sequence 185 True
# DPC Extracted features for sequence 186 True
# DPC Extracted features for sequence 187 True
# DPC Extracted features for sequence 188 True
# DPC Extracted features for sequence 189 True
# DPC Extracted features for sequence 190 True
# DPC Extracted features for sequence 191 True
# DPC Extracted features for sequence 192 True
# DPC Extracted features for sequence 193 True
# DPC Extracted features for sequence 194 True
# DPC Extracted features for sequence 195 True
# DPC Extracted features for sequence 196 True
# DPC Extracted features for sequence 197 True
# DPC Extracted features for sequence 198 True
# DPC Extracted features for sequence 199 True
# DPC Extracted features for sequence 200 True
# DPC Extracted features for sequence 201 True
# DPC Extracted features for sequence 202 True
# DPC Extracted features for sequence 203 True
# DPC Extracted features for sequence 204 True
# DPC Extracted features for sequence 205 True
# DPC Extracted features for sequence 206 True
# DPC Extracted features for sequence 207 True
# DPC Extracted features for sequence 208 True
# DPC Extracted features for sequence 209 True
# DPC Extracted features for sequence 210 True
# DPC Extracted features for sequence 211 True
# DPC Extracted features for sequence 212 True
# DPC Extracted features for sequence 213 True
# DPC Extracted features for sequence 214 True
# DPC Extracted features for sequence 215 True
# DPC Extracted features for sequence 216 True
# DPC Extracted features for sequence 217 True
# DPC Extracted features for sequence 218 True
# DPC Extracted features for sequence 219 True
# DPC Extracted features for sequence 220 True
# DPC Extracted features for sequence 221 True
# DPC Extracted features for sequence 222 True
# DPC Extracted features for sequence 223 True
# DPC Extracted features for sequence 224 True
# DPC Extracted features for sequence 225 True
# DPC Extracted features for sequence 226 True
# DPC Extracted features for sequence 227 True
# DPC Extracted features for sequence 228 True
# DPC Extracted features for sequence 229 True
# DPC Extracted features for sequence 230 True
# DPC Extracted features for sequence 231 True
# DPC Extracted features for sequence 232 True
# DPC Extracted features for sequence 233 True
# DPC Extracted features for sequence 234 True
# DPC Extracted features for sequence 235 True
# DPC Extracted features for sequence 236 True
# DPC Extracted features for sequence 0 False
# DPC Extracted features for sequence 1 False
# DPC Extracted features for sequence 2 False
# DPC Extracted features for sequence 3 False
# DPC Extracted features for sequence 4 False
# DPC Extracted features for sequence 5 False
# DPC Extracted features for sequence 6 False
# DPC Extracted features for sequence 7 False
# DPC Extracted features for sequence 8 False
# DPC Extracted features for sequence 9 False
# DPC Extracted features for sequence 10 False
# DPC Extracted features for sequence 11 False
# DPC Extracted features for sequence 12 False
# DPC Extracted features for sequence 13 False
# DPC Extracted features for sequence 14 False
# DPC Extracted features for sequence 15 False
# DPC Extracted features for sequence 16 False
# DPC Extracted features for sequence 17 False
# DPC Extracted features for sequence 18 False
# DPC Extracted features for sequence 19 False
# DPC Extracted features for sequence 20 False
# DPC Extracted features for sequence 21 False
# DPC Extracted features for sequence 22 False
# DPC Extracted features for sequence 23 False
# DPC Extracted features for sequence 24 False
# DPC Extracted features for sequence 25 False
# DPC Extracted features for sequence 26 False
# DPC Extracted features for sequence 27 False
# DPC Extracted features for sequence 28 False
# DPC Extracted features for sequence 29 False
# DPC Extracted features for sequence 30 False
# DPC Extracted features for sequence 31 False
# DPC Extracted features for sequence 32 False
# DPC Extracted features for sequence 33 False
# DPC Extracted features for sequence 34 False
# DPC Extracted features for sequence 35 False
# DPC Extracted features for sequence 36 False
# DPC Extracted features for sequence 37 False
# DPC Extracted features for sequence 38 False
# DPC Extracted features for sequence 39 False
# DPC Extracted features for sequence 40 False
# DPC Extracted features for sequence 41 False
# DPC Extracted features for sequence 42 False
# DPC Extracted features for sequence 43 False
# DPC Extracted features for sequence 44 False
# DPC Extracted features for sequence 45 False
# DPC Extracted features for sequence 46 False
# DPC Extracted features for sequence 47 False
# DPC Extracted features for sequence 48 False
# DPC Extracted features for sequence 49 False
# DPC Extracted features for sequence 50 False
# DPC Extracted features for sequence 51 False
# DPC Extracted features for sequence 52 False
# DPC Extracted features for sequence 53 False
# DPC Extracted features for sequence 54 False
# DPC Extracted features for sequence 55 False
# DPC Extracted features for sequence 56 False
# DPC Extracted features for sequence 57 False
# DPC Extracted features for sequence 58 False
# DPC Extracted features for sequence 59 False
# DPC Extracted features for sequence 60 False
# DPC Extracted features for sequence 61 False
# DPC Extracted features for sequence 62 False
# DPC Extracted features for sequence 63 False
# DPC Extracted features for sequence 64 False
# DPC Extracted features for sequence 65 False
# DPC Extracted features for sequence 66 False
# DPC Extracted features for sequence 67 False
# DPC Extracted features for sequence 68 False
# DPC Extracted features for sequence 69 False
# DPC Extracted features for sequence 70 False
# DPC Extracted features for sequence 71 False
# DPC Extracted features for sequence 72 False
# DPC Extracted features for sequence 73 False
# DPC Extracted features for sequence 74 False
# DPC Extracted features for sequence 75 False
# DPC Extracted features for sequence 76 False
# DPC Extracted features for sequence 77 False
# DPC Extracted features for sequence 78 False
# DPC Extracted features for sequence 79 False
# DPC Extracted features for sequence 80 False
# DPC Extracted features for sequence 81 False
# DPC Extracted features for sequence 82 False
# DPC Extracted features for sequence 83 False
# DPC Extracted features for sequence 84 False
# DPC Extracted features for sequence 85 False
# DPC Extracted features for sequence 86 False
# DPC Extracted features for sequence 87 False
# DPC Extracted features for sequence 88 False
# DPC Extracted features for sequence 89 False
# DPC Extracted features for sequence 90 False
# DPC Extracted features for sequence 91 False
# DPC Extracted features for sequence 92 False
# DPC Extracted features for sequence 93 False
# DPC Extracted features for sequence 94 False
# DPC Extracted features for sequence 95 False
# DPC Extracted features for sequence 96 False
# DPC Extracted features for sequence 97 False
# DPC Extracted features for sequence 98 False
# DPC Extracted features for sequence 99 False
# DPC Extracted features for sequence 100 False
# DPC Extracted features for sequence 101 False
# DPC Extracted features for sequence 102 False
# DPC Extracted features for sequence 103 False
# DPC Extracted features for sequence 104 False
# DPC Extracted features for sequence 105 False
# DPC Extracted features for sequence 106 False
# DPC Extracted features for sequence 107 False
# DPC Extracted features for sequence 108 False
# DPC Extracted features for sequence 109 False
# DPC Extracted features for sequence 110 False
# DPC Extracted features for sequence 111 False
# DPC Extracted features for sequence 112 False
# DPC Extracted features for sequence 113 False
# DPC Extracted features for sequence 114 False
# DPC Extracted features for sequence 115 False
# DPC Extracted features for sequence 116 False
# DPC Extracted features for sequence 117 False
# DPC Extracted features for sequence 118 False
# DPC Extracted features for sequence 119 False
# DPC Extracted features for sequence 120 False
# DPC Extracted features for sequence 121 False
# DPC Extracted features for sequence 122 False
# DPC Extracted features for sequence 123 False
# DPC Extracted features for sequence 124 False
# DPC Extracted features for sequence 125 False
# DPC Extracted features for sequence 126 False
# DPC Extracted features for sequence 127 False
# DPC Extracted features for sequence 128 False
# DPC Extracted features for sequence 129 False
# DPC Extracted features for sequence 130 False
# DPC Extracted features for sequence 131 False
# DPC Extracted features for sequence 132 False
# DPC Extracted features for sequence 133 False
# DPC Extracted features for sequence 134 False
# DPC Extracted features for sequence 135 False
# DPC Extracted features for sequence 136 False
# DPC Extracted features for sequence 137 False
# DPC Extracted features for sequence 138 False
# DPC Extracted features for sequence 139 False
# DPC Extracted features for sequence 140 False
# DPC Extracted features for sequence 141 False
# DPC Extracted features for sequence 142 False
# DPC Extracted features for sequence 143 False
# DPC Extracted features for sequence 144 False
# DPC Extracted features for sequence 145 False
# DPC Extracted features for sequence 146 False
# DPC Extracted features for sequence 147 False
# DPC Extracted features for sequence 148 False
# DPC Extracted features for sequence 149 False
# DPC Extracted features for sequence 150 False
# DPC Extracted features for sequence 151 False
# DPC Extracted features for sequence 152 False
# DPC Extracted features for sequence 153 False
# DPC Extracted features for sequence 154 False
# DPC Extracted features for sequence 155 False
# DPC Extracted features for sequence 156 False
# DPC Extracted features for sequence 157 False
# DPC Extracted features for sequence 158 False
# DPC Extracted features for sequence 159 False
# DPC Extracted features for sequence 160 False
# DPC Extracted features for sequence 161 False
# DPC Extracted features for sequence 162 False
# DPC Extracted features for sequence 163 False
# DPC Extracted features for sequence 164 False
# DPC Extracted features for sequence 165 False
# DPC Extracted features for sequence 166 False
# DPC Extracted features for sequence 167 False
# DPC Extracted features for sequence 168 False
# DPC Extracted features for sequence 169 False
# DPC Extracted features for sequence 170 False
# DPC Extracted features for sequence 171 False
# DPC Extracted features for sequence 172 False
# DPC Extracted features for sequence 173 False
# DPC Extracted features for sequence 174 False
# DPC Extracted features for sequence 175 False
# DPC Extracted features for sequence 176 False
# DPC Extracted features for sequence 177 False
# DPC Extracted features for sequence 178 False
# DPC Extracted features for sequence 179 False
# DPC Extracted features for sequence 180 False
# DPC Extracted features for sequence 181 False
# DPC Extracted features for sequence 182 False
# DPC Extracted features for sequence 183 False
# DPC Extracted features for sequence 184 False
# DPC Extracted features for sequence 185 False
# DPC Extracted features for sequence 186 False
# DPC Extracted features for sequence 187 False
# DPC Extracted features for sequence 188 False
# DPC Extracted features for sequence 189 False
# DPC Extracted features for sequence 190 False
# DPC Extracted features for sequence 191 False
# DPC Extracted features for sequence 192 False
# DPC Extracted features for sequence 193 False
# DPC Extracted features for sequence 194 False
# DPC Extracted features for sequence 195 False
# DPC Extracted features for sequence 196 False
# DPC Extracted features for sequence 197 False
# DPC Extracted features for sequence 198 False
# DPC Extracted features for sequence 199 False
# DPC Extracted features for sequence 200 False
# DPC Extracted features for sequence 201 False
# DPC Extracted features for sequence 202 False
# DPC Extracted features for sequence 203 False
# DPC Extracted features for sequence 204 False
# DPC Extracted features for sequence 205 False
# DPC Extracted features for sequence 206 False
# DPC Extracted features for sequence 207 False
# DPC Extracted features for sequence 208 False
# DPC Extracted features for sequence 209 False
# DPC Extracted features for sequence 210 False
# DPC Extracted features for sequence 211 False
# DPC Extracted features for sequence 212 False
# DPC Extracted features for sequence 213 False
# DPC Extracted features for sequence 214 False
# DPC Extracted features for sequence 215 False
# DPC Extracted features for sequence 216 False
# DPC Extracted features for sequence 217 False
# DPC Extracted features for sequence 218 False
# DPC Extracted features for sequence 219 False
# DPC Extracted features for sequence 220 False
# DPC Extracted features for sequence 221 False
# DPC Extracted features for sequence 222 False
# DPC Extracted features for sequence 223 False
